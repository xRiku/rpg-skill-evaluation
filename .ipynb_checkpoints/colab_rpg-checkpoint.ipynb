# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import re
import spacy
# from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer

nlp = spacy.load("en_core_web_sm")

sns.set_theme()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-c254082e4770> in <module>
#       6 import re
#       7 import spacy
# ----> 8 from wordcloud import WordCloud
#       9 from sklearn.feature_extraction.text import TfidfVectorizer
#      10
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
def wordcloud(text):
  wordcloud = WordCloud(background_color="white").generate(text)
  plt.figure(figsize=(10,10))
  plt.imshow(wordcloud, interpolation='bilinear')
  plt.axis("off")

# wordcloud(' '.join(df1['text']))

# %%
# Abertura dos arquivos
podcast_file = open('general_podcasts.csv', mode='r')
skills_file = open('skills_dataset.csv', mode='r')
CR_file = open('CR_skills_dataset.csv', mode='r')

# %% [markdown]
# # Podcast

# %%
# Transforma os dados do csv em um dataframe
podcast_df = pd.read_csv(podcast_file)

# %%
# Substitui espaços em branco por NaN
podcast_df = podcast_df.replace(r'^\s*$', np.NaN, regex=True)
# Vertifica número de linhas nulas para cada coluna do arquivo
podcast_df.isnull().sum()
# Out:
# skill            0
# backward_text    0
# check_line       0
# original_name    0
# dtype: int64

# %%
# Aplica uma função que limpa espaços em branco antes e depois da skill, além de passar para letra minúscula
podcast_df["skill"] = podcast_df["skill"].apply(lambda x: x.strip().lower())

# Agrupa e conta o número frases por skill, também coloca as skills em ordem alfabética 
podcast_pps = podcast_df.groupby(by="skill", sort=True).count()['backward_text']
podcast_pps
# Out:
# skill
# acrobatics          82
# animal handling     47
# arcana             103
# athletics          137
# concentration        1
# deception          105
# disguise             3
# history             42
# insight             87
# intimidation        42
# investigation      204
# medicine            41
# nature              49
# perception         405
# performance         77
# persuasion          63
# religion            15
# sleight of hand     41
# stealth            125
# survival            64
# Name: backward_text, dtype: int64

# %%
podcast_pps["persuasion"]
# Out:
# 63

# %% [markdown]
# # Skills

# %%
# Transforma os dados do csv em um dataframe
skills_df = pd.read_csv(skills_file)

# %%
# Substitui os campos com espaço em branco por NaN
skills_df = skills_df.replace(r'^\s*$', np.NaN, regex=True)
# Vertifica número de linhas nulas para cada coluna do arquivo
skills_df.isnull().sum()
# Out:
# skill             54
# backward_text      0
# original_name    155
# dtype: int64

# %%
# Lista linhas que estão com NaN no campo skill
skills_df.loc[skills_df["skill"].isnull()]
# Out:
#       skill                                      backward_text original_name
# 7692    NaN  >The remaining trio of Goblins immediately lau...            #4
# 7693    NaN  >The remaining trio of Goblins immediately lau...            #5
# 7694    NaN  >The remaining trio of Goblins immediately lau...            #6
# 9958    NaN  >Sticks bound off scale and fists find only ai...           12)
# 9961    NaN  >Sticks bound off scale and fists find only ai...           12)
# 9964    NaN  >Sticks bound off scale and fists find only ai...           10)
# 9967    NaN  >Sticks bound off scale and fists find only ai...           10)
# 10064   NaN                                      > Medicus #2           (13)
# 10080   NaN                                        >Vigilance             10
# 10117   NaN                                         >Vigilant         10-1=9
# 11099   NaN  >As the man Rory dismisses him and swaggers to...           14)
# 12277   NaN  >As the man Rory dismisses him and swaggers to...           14)
# 14461   NaN   style="text-align: center;">Round 3 Arathiel ...           @ 1
# 14463   NaN   style="text-align: center;">Round 3 Arathiel ...           @ 2
# 14722   NaN  >The survivng Jackalwere growls at Xodar and t...           @ 2
# 18484   NaN   style="text-align: center;">Round 1  swings w...            @​
# 18486   NaN   style="text-align: center;">Round 1  swings w...            @​
# 18488   NaN   style="text-align: center;">Round 1  swings w...            @​
# 18490   NaN   style="text-align: center;">Round 1  swings w...            @​
# 24016   NaN  >Dr. S leads you down the clean, bare concrete...           ???
# 26892   NaN  >Slicer's Defense Rolls#1   5 successes#2   2 ...            #1
# 26893   NaN  >Slicer's Defense Rolls#1   5 successes#2   2 ...            #2
# 27099   NaN                                    >Gear rolls...            # 1
# 27100   NaN                                    >Gear rolls...            # 2
# 29018   NaN   style="text-align: center;">Today's Encounter...           ???
# 29020   NaN   style="text-align: center;">Today's Encounter...           ???
# 29022   NaN   style="text-align: center;">Today's Encounter...           ???
# 37737   NaN                     >Take from this what you will             1.
# 37738   NaN                     >Take from this what you will             2.
# 37739   NaN                     >Take from this what you will             3.
# 37740   NaN                     >Take from this what you will             4.
# 37741   NaN                     >Take from this what you will             5.
# 37742   NaN                     >Take from this what you will             1.
# 37743   NaN                     >Take from this what you will             2.
# 37744   NaN                     >Take from this what you will             3.
# 37745   NaN                     >Take from this what you will             4.
# 37746   NaN                     >Take from this what you will             5.
# 46813   NaN  >(2×) Bite XX+3Scout#3 - Halfred (fwd)*Bites f...            #3
# 46814   NaN  >(2×) Bite XX+3Scout#3 - Halfred (fwd)*Bites f...            #4
# 47998   NaN  > narrows her eyes, lets her focus attenuate a...          70%)
# 48333   NaN  >He blinks for a moment, collects himself and ...      .45 (60)
# 48340   NaN  >Jackon fires again, shouting, "RUN!"The bulle...      .45 (60)
# 48346   NaN  >"I don't think so." Instead of trying to run,...      .45 (60)
# 48633   NaN  >ooc: Wolf2 protection v. TN14 Avoids piercing...            14
# 48673   NaN  >The brown and black furred wolves that leapt ...            #7
# 48674   NaN  >The brown and black furred wolves that leapt ...            #8
# 48675   NaN  >The brown and black furred wolves that leapt ...            #9
# 48676   NaN  >The brown and black furred wolves that leapt ...           #10
# 48677   NaN  >The brown and black furred wolves that leapt ...           #11
# 48678   NaN  >The brown and black furred wolves that leapt ...           #12
# 48690   NaN  >The Easterlings counter-attack with pikes aft...            #2
# 48691   NaN  >The Easterlings counter-attack with pikes aft...            #3
# 48692   NaN  >The Easterlings counter-attack with pikes aft...            #4
# 48693   NaN  >The Easterlings counter-attack with pikes aft...            #5

# %%
# Remove todas as linhas com NaN no campo skill
skill_df = skills_df.dropna(subset=["skill"], inplace=True)
# Soma as linhas com NaN no campo skill
skills_df["skill"].isnull().sum()
# Out:
# 0

# %%
# Aplica uma função que transforma o campo em string,
# limpa espaços em branco antes e depois da string, além de passar para letra minúscula
skills_df["skill"] = skills_df["skill"].apply(lambda x: str(x).strip().lower())
skills_df
# Out:
#              skill                                      backward_text  \
# 0          history  > nodded accepting the parcel by ’s hands, in ...
# 1      performance  > nodded accepting the parcel by ’s hands, in ...
# 2           arcana  >"Aye, give me but a moment to study this piec...
# 3         medicine  >(Healing roll: to see if he can remember anyt...
# 4         survival  >(OOC: Travel roll. Do we need even to test co...
# ...            ...                                                ...
# 49800     survival   The great beast leaps through the camp, pierc...
# 49801   perception   As the darkness surrounds and your feeble fir...
# 49802      stealth   [OOC: For anyone new to TOR or unfamiliar wit...
# 49803   perception   [OOC: For anyone new to TOR or unfamiliar wit...
# 49804      stealth   @ Milo: The sounds of movement far off in the...
#
#       original_name
# 0              Lore
# 1              Song
# 2             Craft
# 3           Healing
# 4            Travel
# ...             ...
# 49800       Hunting
# 49801     Awareness
# 49802       Stealth
# 49803     Awareness
# 49804       Stealth
#
# [49751 rows x 3 columns]

# %%
# Agrupa e conta o número frases por skill, além de colocar em ordem alfabética de skill.
skills_pps = skills_df.groupby(by="skill", sort=True).count()["backward_text"]
skills_pps
# Out:
# skill
# #1 atk                  14
# #2                       1
# #2 atk                  15
# #3 atk                  11
# #4 atk                   4
#                         ..
# ​hit 61                  3
# ​insight check           1
# ​opportunity attack      1
# ​str                     1
# ​willpower hard  @30     1
# Name: backward_text, Length: 9307, dtype: int64

# %%
skills_pps["persuasion"]
# Out:
# 540

# %% [markdown]
# # CR skills

# %%
# Transforma os dados do csv em um dataframe
CR_df = pd.read_csv(CR_file)

# %%
# Substitui campos com espaço em branco por NaN
CR_df = CR_df.replace(r'^\s*$', np.NaN, regex=True)
# Vertifica número de linhas nulas para cada coluna do arquivo
CR_df.isnull().sum()
# Out:
# skill            0
# backward_text    0
# check_line       0
# dtype: int64

# %%
# Aplica uma função que limpa espaços em branco antes e depois da skill, além de passar para letra minúscula
CR_df['skill'] = CR_df['skill'].apply(lambda x: x.strip().lower())
CR_df
# Out:
#               skill                                      backward_text  \
# 0        persuasion  ‘Cause the dwarves weren't fans of nobody with...
# 1        persuasion  Careful. (sighs) Not as often as I get woken u...
# 2        persuasion  You're so… we just heard you're so… impressive...
# 3        persuasion  they're terrible people. Anyway, my associates...
# 4        persuasion  Anyway, my associates and I were wondering if ...
# ...             ...                                                ...
# 5249  investigation  (laughter) (sings) Continuity. Roll for contin...
# 5250        insight  wall. There is a very, very faint scratch into...
# 5251      deception  advice from when it comes to administrating my...
# 5252        stealth  I was under the assumption that you had to be ...
# 5253     perception  clean up. When Fjord's taking a bath, I'm goin...
#
#                                              check_line
# 0     and rolled pretty damn well on a persuasion ch...
# 1                         Matt: Make a persuasion roll.
# 2           Matt: (To Marisha) Make a persuasion check.
# 3     Matt: Make a persuasion roll. You can assist i...
# 4     Taliesin: I'm assisting in this persuasion rol...
# ...                                                 ...
# 5249                               investigation check.
# 5250                             TRAVIS: Insight check.
# 5251                      MATT: Make a deception check.
# 5252     MATT: Okay. Go ahead and make a stealth check.
# 5253      MATT: You do. Make a perception check, Molly.
#
# [5254 rows x 3 columns]

# %%
# Agrupa e conta o número frases por skill, também coloca as skills em ordem alfabética 
# PPS = phrases per skill
CR_pps = CR_df.groupby(by="skill", sort=True).count()["backward_text"]
CR_pps
# Out:
# skill
# acrobatics          236
# animal handling      28
# arcana              152
# athletics           371
# deception           222
# history              93
# insight             445
# intimidation        111
# investigation       641
# medicine             93
# nature              183
# perception         1431
# performance          44
# persuasion          333
# religion            105
# sleight of hand      57
# stealth             609
# survival            100
# Name: backward_text, dtype: int64

# %%
CR_pps["persuasion"]
# Out:
# 333

# %% [markdown]
# # Tabela total

# %%
# Dataframe resultado da concatenação dos três dataframes
concatenated_df = pd.concat([podcast_df,skills_df,CR_df])

# %%
# Agrupa e conta o número frases por skill, também coloca as skills em ordem alfabética 
total_pps = concatenated_df.groupby("skill", sort=True).count()['backward_text']
total_pps
# Out:
# skill
# #1 atk                  14
# #2                       1
# #2 atk                  15
# #3 atk                  11
# #4 atk                   4
#                         ..
# ​hit 61                  3
# ​insight check           1
# ​opportunity attack      1
# ​str                     1
# ​willpower hard  @30     1
# Name: backward_text, Length: 9307, dtype: int64

# %%
total_pps["persuasion"]
# Out:
# 936

# %%
"""
    Função que transforma uma lista de palavras bem formatadas em um dicionário de ocorrências.
    Ex.:
        > x = ['Philipe', 'Jc', 'Victor', 'Philipe', 'Jc', 'Victor', 'Victor', 'Jc']
        > ocorrencias(x)
        > {'Philipe': 2, 'Jc': 3, 'Victor': 3}
"""
def ocorrencias(lista):
    dict_ocorrencias = {}
    for i in lista:
        if i in dict_ocorrencias:
            dict_ocorrencias[i] += 1
        else:
            dict_ocorrencias[i] = 1
    return dict_ocorrencias

# %%
"""
    Função que dado um dicionário de ocorrências ou lista bem formatada,
    plota um gráfico com as palavras com maior ocorrência (15 por padrão).
"""
def bar_graphic(dicionario=None, paleta="rocket", lista_ocorrencias = None, max=15, dim=(12,9)):
    # Se não tiver dicionario, vai ter uma lista
    if dicionario is None:
        if lista_ocorrencias is not None:
            # A lista é então convertida para dicionario através da função de ocorrencias
            dicionario = ocorrencias(lista_ocorrencias)
    
    # O dicionario é transformado em dataframe para melhor manipulação
    df = pd.DataFrame(dicionario.items(), columns=["key", "value"])
    # Dataframe ordenado de forma decrescente e com o máximo estipulado
    df = df.sort_values(by="value", ascending=False).head(max)
    
    # É então re-convertido em dicionario
    top_dicionario = dict(df.values)
    
    # As chaves e valores são convertidas em lista para auxiliar na plotagem do gráfico
    palavras = list(top_dicionario.keys())
    valores = list(top_dicionario.values())
    
    ## Plot
    # Define dimensões para o gráfico
    fig_dims = dim
    fig, ax = plt.subplots(figsize=fig_dims)
    # Configura o eixo, paleta e dimensões do gráfico
    plot = sns.barplot(x=palavras,y=valores, palette=paleta, ax=ax)
    # Define o título do gráfico
    plt.title(f'Top {max} Ocorrências')
    # Rotaciona a legenda de cada barra e plota o gráfico
    plt.setp(plot.get_xticklabels(), rotation=45)

# %%
total_pps_dict = total_pps.to_dict()
total_pps_dict
# Out:
# {'#1 atk': 14,
#  '#2': 1,
#  '#2 atk': 15,
#  '#3 atk': 11,
#  '#4 atk': 4,
#  '-damage': 1,
#  '1': 1,
#  '1 dmg': 1,
#  '1 to 4 silver darter 5 rabbit viper 6 the bad snake': 1,
#  '15-12=16': 1,
#  '16-12=17': 1,
#  '1d20': 1,
#  '1d6': 1,
#  '1d61': 1,
#  '2': 1,
#  '2 dmg': 1,
#  '3': 1,
#  '3 dmg': 1,
#  '3rd try': 1,
#  '4': 1,
#  '5 = volkbert': 1,
#  '@26': 1,
#  '_2nd_crit': 1,
#  '_crit': 1,
#  '_dodge': 1,
#  '_extradamage': 1,
#  '_parry': 1,
#  'a': 3,
#  'a  heavin   amp  a hoin': 1,
#  'a  o    elixir of life': 1,
#  'a  o    life elixir': 1,
#  'a att': 3,
#  'a bitter memory': 1,
#  'a blip on my scope': 1,
#  'a bold display': 1,
#  'a d   to add modifiers to for whatever is needed here': 1,
#  'a dam': 3,
#  'a die': 14,
#  'a die   wits': 1,
#  'a die  wits and bonus': 1,
#  'a disadvantage': 1,
#  'a feinting guard': 1,
#  'a good spine throttling': 1,
#  'a init': 1,
#  'a little extra whip tlc for': 1,
#  'a mysterious die of fate': 1,
#  'a or d damage': 1,
#  'a paladin prepares initiative': 1,
#  'a roll': 1,
#  'a s': 4,
#  'a savin  the boat driver': 1,
#  'a shillelagh for': 1,
#  'a1.ad': 1,
#  'a1.base': 1,
#  'a1.dmg': 1,
#  'a2.ad': 1,
#  'a2.base': 1,
#  'a2.dmg': 1,
#  'abi': 2,
#  'abi con': 4,
#  'abi con save': 1,
#  'abi empower': 1,
#  'abi heal': 1,
#  'abi wis': 1,
#  'ability scores': 1,
#  'absent minded professor': 1,
#  'ac  melee with shield': 1,
#  'ac  no shield': 4,
#  'ac shield minus fierce': 3,
#  'academics  comms': 1,
#  'access points': 1,
#  'access random memories careful overcome': 1,
#  'access records': 1,
#  'accidentaltusk brune': 1,
#  'accidentaltusk gaden': 1,
#  'accidentaltusk tally': 1,
#  'accomplish a feat': 1,
#  'accuracy': 5,
#  'accurate': 42,
#  'accurate        flanking': 1,
#  'accurate       we are flanking now yes': 2,
#  'accurate 102 advantage-3 defense = 9 2 attacks with 2 chances to hit': 1,
#  'acd dmg': 1,
#  'ace': 2,
#  'acerto': 2,
#  'acerto da flecha explosiva': 1,
#  'acerto flecha': 1,
#  'acerto guarda': 2,
#  'acerto no segundo alvo nh': 1,
#  'achilles die': 1,
#  'acid': 15,
#  'acid damage': 4,
#  'acid splash damage': 1,
#  'acolytes': 1,
#  'acordado ht': 1,
#  'acorn': 1,
#  'acorobatic roll': 1,
#  'acquisitive eye': 1,
#  'acro 1': 1,
#  'acro a': 1,
#  'acro b': 1,
#  'acrobacia': 3,
#  'acrobacia  contra cd': 2,
#  'acrobatics': 506,
#  'acrobatics  if req': 1,
#  'acrobatics  just in case': 1,
#  'acrobatics  to help with fall': 1,
#  'acrobatics balance': 1,
#  'acrobatics check': 1,
#  'acrobatics dc': 1,
#  'acrobatics if needed': 1,
#  'acrobatics to jump down and not faceplant': 1,
#  'act': 1,
#  'act under fire': 24,
#  'act under fire   spooky intense': 1,
#  'act under fire  cool': 1,
#  'act under fire  hard': 2,
#  'act under fire  spooky intense': 2,
#  'act under fire  weird': 1,
#  'act under pressure': 2,
#  'act under pressure to attempt to use gallifreyan technology': 1,
#  'act up    medals': 2,
#  'act up w guts': 2,
#  'acting': 4,
#  'acting nh': 2,
#  'acting nh    iq': 1,
#  'acting soldado': 1,
#  'acting under fire   hot': 1,
#  'acting up': 1,
#  'action': 4,
#  'action die': 11,
#  'action die   heart   bonds': 1,
#  'action order': 1,
#  'action point': 3,
#  'action surge': 1,
#  'action to close': 1,
#  'actions surge': 1,
#  'activation': 6,
#  'active sensor sweep overcome with technology': 1,
#  'activeperception': 1,
#  'acuity': 2,
#  'acumen  musada': 1,
#  'adalfinn': 3,
#  'adalfinn leader': 1,
#  'added weight': 1,
#  'additional bonus die': 1,
#  'additional damage die': 2,
#  'additional stealth': 1,
#  'adorkable': 1,
#  'adv': 376,
#  'adv   dorakas': 2,
#  'adv  maybe': 1,
#  'adv  smoke chaos etc': 1,
#  'adv  unhurried': 1,
#  'adv 1': 1,
#  'adv 2': 1,
#  'adv attack': 4,
#  'adv cha save': 1,
#  'adv cuz injured': 2,
#  'adv dash': 1,
#  'adv dis': 6,
#  'adv disadv': 2,
#  'adv don': 2,
#  'adv favorite terrain enemy goblin orc': 1,
#  'adv for metal armor': 1,
#  'adv for smell based perception': 1,
#  'adv if dash stuck': 1,
#  'adv invisible': 2,
#  'adv maybe': 4,
#  'adv metal': 1,
#  'adv metal armor': 1,
#  'adv seeing and hearing': 1,
#  'adv shocking grasp': 1,
#  'adv stealth': 1,
#  'advangage': 2,
#  'advant': 21,
#  'advant on restrained': 1,
#  'advantage': 191,
#  'advantage #1': 1,
#  'advantage #2': 1,
#  'advantage #3': 1,
#  'advantage attack vs power': 1,
#  'advantage daria s help': 1,
#  'advantage dice': 3,
#  'advantage die': 2,
#  'advantage die  for being heroic': 1,
#  'advantage disadvantage': 28,
#  'advantage due to gnome': 1,
#  'advantage due to shield': 1,
#  'advantage everald': 1,
#  'advantage from blocking': 1,
#  'advantage from crowbar': 1,
#  'advantage from shield': 1,
#  'advantage hearing seeing': 1,
#  'advantage investigation for talan s search': 1,
#  'advantage keen sight': 1,
#  'advantage mister earl': 1,
#  'advantage on cha roll': 1,
#  'advantage on dex save': 2,
#  'advantage on stealth for thanks to the blessing': 1,
#  'advantage perception': 1,
#  'advantage prone': 1,
#  'advantage reckless attack': 1,
#  'advantage roll': 3,
#  'advantage seeing and hearing': 7,
#  'advantage str': 1,
#  'advantagedc': 1,
#  'advantages': 1,
#  'advantsge': 1,
#  'advat rage': 1,
#  'advatk': 6,
#  'advbow': 1,
#  'advcross': 1,
#  'advcrossbow': 2,
#  'adventurer affairs public relations division persuasion': 1,
#  'adventurers': 1,
#  'adversary': 1,
#  'advgrapple': 1,
#  'advntage': 1,
#  'advpersuade': 1,
#  'advshockgrab': 1,
#  'advshockgrasp': 1,
#  'advsplash': 1,
#  'advstealth': 1,
#  'advsurvival': 1,
#  'advtange atk': 1,
#  'aeric': 1,
#  'af dmg rnd': 2,
#  'affiliation': 3,
#  'aflah invocation@57': 1,
#  'afternoon': 1,
#  'ag': 5,
#  'again': 3,
#  'against': 1,
#  'against corruption': 2,
#  'against marielle': 1,
#  'age': 8,
#  'ages x': 1,
#  'aggressive  hard': 1,
#  'aggressive shooting': 1,
#  'agi': 14,
#  'agi  ass  with advantage  dice': 1,
#  'agi ass bonus': 1,
#  'agil  inject the monster': 1,
#  'agilities': 1,
#  'agility': 30,
#  'agility   hunter with adv': 1,
#  'agility   melee   all out attack': 1,
#  'agility  sneak': 1,
#  'agility barbarian': 1,
#  'agility challenge': 5,
#  'agility challenge to grab the centipede': 1,
#  'agility challenge with 2 banes': 1,
#  'agility challenge with one bane': 1,
#  'agility hunter': 1,
#  'agility hunter with plains born': 1,
#  'agility melee': 5,
#  'agility melee all out attack': 1,
#  'agility melee defensive stance': 3,
#  'agility ranged': 4,
#  'agility ranged rangepen armourby': 1,
#  'agility to cut a purse': 1,
#  'agility with favor': 1,
#  'agilty': 1,
#  'ah': 2,
#  'aid': 7,
#  'aid adv': 1,
#  'aid another': 1,
#  'aid interfere': 3,
#  'aid observe': 1,
#  'aid roll from charismatic elf who can t use cha for this  but can use bond': 1,
#  'aid with clay': 1,
#  'aidan': 2,
#  'aiofe': 1,
#  'air drums': 1,
#  'air social   void': 1,
#  'ais init': 5,
#  'aiss': 2,
#  'akarmi': 1,
#  'alacrity': 1,
#  'alacrity caa': 1,
#  'alacrity for turn order': 2,
#  'alarion': 6,
#  'alchemists fire': 1,
#  'alchemy': 4,
#  'aleat rio  nh': 9,
#  'alertness': 8,
#  'alertness  wis': 1,
#  'alertness empathy  same   of dice': 1,
#  'alertness wis': 1,
#  'alignment': 5,
#  'all': 1,
#  'all at': 1,
#  'all out called shot bite  strength   brawl': 1,
#  'allies battle roll': 1,
#  'allies in combat': 4,
#  'also some owl': 1,
#  'altar': 1,
#  'alvo': 23,
#  'alvo     nh': 4,
#  'alvo     tiro': 1,
#  'alvo    ht': 1,
#  'alvo    nh': 4,
#  'alvo   nh': 6,
#  'alvo  tiro': 1,
#  'am i missing blood': 1,
#  'amarla   of bites': 3,
#  'amarla damage': 3,
#  'amarla hit location': 1,
#  'ambush spear': 1,
#  'amdir awareness': 1,
#  'amdir lore': 1,
#  'amdir search': 1,
#  'amdir travel 1': 1,
#  'amdir travel 2': 1,
#  'amdir wisdom tn =16': 1,
#  'ammo': 1,
#  'ammo save': 1,
#  'amp party': 1,
#  'anaaaais  can you hear me': 1,
#  'anais': 1,
#  'analyze data': 1,
#  'ananda agility': 2,
#  'ancestral healing': 1,
#  'anchoring to center mast': 1,
#  'and for odur': 1,
#  'and i know what you re thinking': 1,
#  'and some hit points': 1,
#  'and third': 1,
#  'and wallace': 1,
#  'andrath damage': 1,
#  'angel kit': 1,
#  'angelic guide': 1,
#  'animal handeling': 3,
#  'animal handling': 145,
#  'animal handling  tn': 1,
#  'animal handling check': 1,
#  'animan handling': 1,
#  'animated books': 1,
#  'anko con save': 1,
#  'anko initiative': 6,
#  'ankohealing': 1,
#  'anna': 2,
#  'annette perception': 1,
#  'another d': 1,
#  'another roll': 1,
#  'another sectrit die': 1,
#  'ant initiative': 1,
#  'anti virus': 1,
#  'any chance of adv': 1,
#  'any skill': 1,
#  'anycrits': 1,
#  'aoe': 1,
#  'aoe burst': 1,
#  'aoe damage': 1,
#  'aoe dmg': 1,
#  'aoife': 1,
#  'aoo': 9,
#  'aoo axe damage': 2,
#  'aoo crit': 1,
#  'aoo dagger if succeeds': 2,
#  'aoo damage': 1,
#  'aoo dmg': 1,
#  'aoo sword': 2,
#  'aoo sword damage': 2,
#  'aoo w axe  if alive': 2,
#  'aoo whip': 1,
#  'ape atk': 3,
#  'ape dex': 1,
#  'ape initiative': 1,
#  'apius': 2,
#  'apius base': 1,
#  'apius s slave handling': 3,
#  'apius wild': 1,
#  'app': 6,
#  'appeal dancer attractive advantage keep highest   dice': 1,
#  'appearance': 12,
#  'appraisal': 1,
#  'appraise': 3,
#  'approach stealthily  tolga   stealth': 1,
#  'aracana': 1,
#  'aragosians fight': 1,
#  'arathielspear': 3,
#  'arcana': 484,
#  'arcana  inc bardic insp': 1,
#  'arcana check': 10,
#  'arcana check  disadv': 1,
#  'arcana dc': 1,
#  'arcana for next post': 1,
#  'arcana in case the scrolls are trapped': 1,
#  'arcana or investigation': 1,
#  'arcana or religion': 1,
#  'arcana to figure out what that was   minus   if religion': 1,
#  'arcana to identify the fog': 1,
#  'arcane': 2,
#  'arcane art': 2,
#  'arcane feedback': 1,
#  'archer': 10,
#  'archer    eomund': 1,
#  'archer    holman': 1,
#  'archer    wes': 1,
#  'archer attack': 10,
#  'archer crit': 1,
#  'archer init': 1,
#  'archer int save': 2,
#  'archer strength check': 1,
#  'archers': 1,
#  'archery': 1,
#  'are you watching closely': 1,
#  'area': 1,
#  'area attack': 1,
#  'area effect pin on and': 1,
#  'area knowledge  france': 1,
#  'area knowledge 14': 1,
#  'ares pistol': 1,
#  'arguing guards': 1,
#  'arm yanking damage to singh': 1,
#  'armor': 26,
#  'armor check': 1,
#  'armor off': 1,
#  'armor roll': 1,
#  'armor vs': 1,
#  'armored': 1,
#  'armour': 43,
#  'armour  this round': 1,
#  'arms': 1,
#  'arremesso': 1,
#  'arrow': 40,
#  'arrow 2': 1,
#  'arrow @ hag thot': 1,
#  'arrow @ ikea reject': 1,
#  'arrow alton': 1,
#  'arrow dmg': 2,
#  'arrow hanna': 1,
#  'arrow hannah': 4,
#  'arrow jr': 3,
#  'arrow one': 1,
#  'arrow tally': 1,
#  'arrow thurmund': 1,
#  'arrow winds': 1,
#  'arrow zeek': 1,
#  'arrows': 2,
#  'arrows usage': 1,
#  'artful  amp  gracious': 1,
#  'artificerknowledge': 1,
#  'as claws': 1,
#  'ask the oracle': 1,
#  'asmeron charisma': 2,
#  'aspar': 2,
#  'assault rifle attack': 1,
#  'assense': 2,
#  'assensing': 3,
#  'assess': 7,
#  'assess a charged situation': 1,
#  'assess injuries': 1,
#  'assess the situation': 4,
#  'assess the situation  superior': 2,
#  'assessing   superior': 1,
#  'assessing armor voss': 1,
#  'assets': 5,
#  'assist': 4,
#  'assistance  tn': 1,
#  'assumed bad perception': 1,
#  'astral': 1,
#  'astral perception': 2,
#  'at': 1,
#  'at advantage': 1,
#  'at advantage since restrained': 1,
#  'at bella': 1,
#  'at belrash': 2,
#  'at berash': 1,
#  'at disadvantage since his target is bloody invisible': 1,
#  'at garyn': 4,
#  'at uriah': 1,
#  'ataque': 47,
#  'ataque   vs guarda': 2,
#  'ataque  nh': 10,
#  'ataque  rifle': 1,
#  'ataque a  o': 1,
#  'ataque cd': 1,
#  'ataque com a mp': 1,
#  'ataque de investida': 1,
#  'ataque de oportunidade': 1,
#  'ataque investida': 2,
#  'ataque na face': 1,
#  'ataque nh': 2,
#  'ataque no cr nio do craig': 1,
#  'ataque no craig': 2,
#  'ataque pistola': 1,
#  'ataque rifle': 1,
#  'ataque rifle diferente': 1,
#  'ataques': 8,
#  'atck': 1,
#  'atheltics': 2,
#  'atheltics 1': 1,
#  'atheltics for staying mounted': 1,
#  'athetics': 1,
#  'athletic  adv': 3,
#  'athletic  if retry': 1,
#  'athletic to tackle him': 1,
#  'athletics': 1049,
#  'athletics  climb': 1,
#  'athletics  throwing': 1,
#  'athletics 2': 1,
#  'athletics 3': 1,
#  'athletics 60': 1,
#  'athletics @ 1625': 1,
#  'athletics adv': 1,
#  'athletics again for a trip': 1,
#  'athletics agility': 1,
#  'athletics check': 13,
#  'athletics climb': 1,
#  'athletics east': 1,
#  'athletics if allowed': 1,
#  'athletics overcome to climb down': 1,
#  'athletics part 2': 1,
#  'athletics plus one bonus die': 1,
#  'athletics ride 1': 1,
#  'athletics roll': 2,
#  'athletics rolls': 1,
#  'athletics to break off combat and take up the pursuit': 1,
#  'athletics to grapple': 1,
#  'athletics to navigate to the bridge': 1,
#  'atio crow': 1,
#  'atk': 406,
#  'atk   adv': 3,
#  'atk   dis': 4,
#  'atk  adv': 1,
#  'atk 1': 1,
#  'atk 2': 1,
#  'atk 3': 1,
#  'atk adv': 2,
#  'atk crit': 1,
#  'atk opp': 1,
#  'atk pb dex': 1,
#  'atk vs': 2,
#  'atk vs rodrick': 1,
#  'atk#2': 3,
#  'atk1': 3,
#  'atk1 adv': 1,
#  'atk2': 5,
#  'atk2 adv': 1,
#  'atkoddly': 1,
#  'atks': 1,
#  'atks  adv': 1,
#  'atkwinds': 1,
#  'atordoamento ht': 1,
#  'att': 1,
#  'att cinder': 1,
#  'attack': 1186,
#  'attack     for drawing weapon': 1,
#  'attack    blue': 1,
#  'attack    green': 1,
#  'attack   adv': 8,
#  'attack   advantage': 1,
#  'attack   anko': 2,
#  'attack   dis': 5,
#  'attack   disad': 6,
#  'attack   disadv': 1,
#  'attack   jargar': 2,
#  'attack  a': 18,
#  'attack  adv': 166,
#  'attack  all out  roll': 1,
#  'attack  as improv weapon': 1,
#  'attack  b': 18,
#  'attack  base': 246,
#  'attack  crit damage': 1,
#  'attack  dagger': 3,
#  'attack  dex': 1,
#  'attack  dex       advantage powerful opponent': 1,
#  'attack  dex      advantage': 1,
#  'attack  dex     powerful opponent': 2,
#  'attack  dis': 4,
#  'attack  discreet': 2,
#  'attack  dmg': 245,
#  'attack  fast unarmed w  feral musing': 1,
#  'attack  leader': 2,
#  'attack  minus shriek': 1,
#  'attack  monsoon vs  st banger': 1,
#  'attack  old captain': 2,
#  'attack  power attack': 1,
#  'attack  ranged': 1,
#  'attack  roll melee agi and no def': 1,
#  'attack  sharpshooter': 1,
#  'attack  skill at arms': 5,
#  'attack  str': 1,
#  'attack  strength': 1,
#  'attack  strong': 1,
#  'attack  strong        adv': 1,
#  'attack  strong vs': 1,
#  'attack  when target arrives': 1,
#  'attack  with penalty die so lowest dice': 1,
#  'attack 1': 1,
#  'attack 1 17': 1,
#  'attack 1 short sword': 1,
#  'attack 15-32-1=13': 1,
#  'attack 2': 1,
#  'attack 2 17': 1,
#  'attack 2 dagger': 1,
#  'attack 76': 1,
#  'attack @ 60': 1,
#  'attack a': 3,
#  'attack ad': 11,
#  'attack adv': 6,
#  'attack advantage': 5,
#  'attack again': 2,
#  'attack against surhak': 1,
#  'attack ais': 4,
#  'attack b': 2,
#  'attack b dis': 1,
#  'attack back': 1,
#  'attack bear': 1,
#  'attack bends 10': 1,
#  'attack boon a': 1,
#  'attack boons': 1,
#  'attack brown': 1,
#  'attack cade': 8,
#  'attack chittering': 1,
#  'attack creature with knife': 1,
#  'attack d': 1,
#  'attack d15': 1,
#  'attack dagger': 2,
#  'attack defense 11': 1,
#  'attack dis': 9,
#  'attack dmg': 1,
#  'attack elf': 6,
#  'attack elf ac': 2,
#  'attack elf accuracy': 2,
#  'attack elf advantage': 1,
#  'attack fierce': 2,
#  'attack fighter': 1,
#  'attack formor': 1,
#  'attack gira': 8,
#  'attack godrick': 1,
#  'attack hot': 2,
#  'attack if successful': 1,
#  'attack io': 7,
#  'attack kobold next to cinder': 1,
#  'attack lasso': 1,
#  'attack m': 1,
#  'attack miranda': 1,
#  'attack morn': 1,
#  'attack odur': 1,
#  'attack odur defense 10': 2,
#  'attack of opportunity': 1,
#  'attack offensive stance': 1,
#  'attack on odur': 2,
#  'attack on the wheel': 2,
#  'attack one': 1,
#  'attack plus horde minus defense and shield vs yar': 1,
#  'attack r': 1,
#  'attack red': 1,
#  'attack reroll': 1,
#  'attack role point blank into melee': 1,
#  'attack roll': 32,
#  'attack ron': 1,
#  'attack run': 5,
#  'attack shortbow': 1,
#  'attack shortsword': 2,
#  'attack skill': 2,
#  'attack slicer': 1,
#  'attack spear': 1,
#  'attack spiritual': 1,
#  'attack str': 2,
#  'attack strong': 1,
#  'attack tall orc': 1,
#  'attack test': 1,
#  'attack the froggy orc': 1,
#  'attack the mook': 1,
#  'attack thom': 2,
#  'attack to disarm': 2,
#  'attack to hit': 1,
#  'attack twice': 2,
#  'attack via fire wall charm charisma occult staff ash pouch field of ashes': 1,
#  'attack via giant fireball charm charisma occult staff ash pouch field of ashes': 1,
#  'attack vs': 3,
#  'attack vs agility': 4,
#  'attack vs eomund s horse tn': 1,
#  'attack vs eomund tn': 1,
#  'attack vs horse tn': 1,
#  'attack vs power': 4,
#  'attack vs rah': 1,
#  'attack vs tall orc': 1,
#  'attack vs tn': 1,
#  'attack w  club': 1,
#  'attack w  dagger': 1,
#  'attack w  dex': 2,
#  'attack w  dexterity': 1,
#  'attack w  dexterity at disadvantage': 1,
#  'attack w  musing': 1,
#  'attack w  power': 5,
#  'attack w  skill at arms': 1,
#  'attack w  skill at arms and chip on the shoulder': 1,
#  'attack w  strength': 3,
#  'attack w bless  supreme leader': 2,
#  'attack westly': 1,
#  'attack with advantage': 1,
#  'attack with advantage plus horde minus defense and shield vs andrath': 1,
#  'attack with bless': 2,
#  'attack with bless  leader': 2,
#  'attack with chain': 1,
#  'attack with claws': 1,
#  'attack with crossbow': 1,
#  'attack with dagger': 1,
#  'attack with dex': 1,
#  'attack with dexterity': 1,
#  'attack with disadvantage': 1,
#  'attack with disavantage': 1,
#  'attack with fight': 1,
#  'attack with flail': 1,
#  'attack with force': 1,
#  'attack with halo': 1,
#  'attack with rapier': 1,
#  'attack with skill at arms': 1,
#  'attack with skill at arms  amp  shattered jaw': 1,
#  'attack with spear     to atk': 1,
#  'attack with wristbow': 1,
#  'attack wolf with seed': 1,
#  'attack1': 5,
#  'attack1.adv': 4,
#  'attack1.base': 9,
#  'attack1.dis': 2,
#  'attack1.dmg': 9,
#  'attack1adv': 2,
#  'attack1dam': 1,
#  'attack2': 8,
#  'attack2 crit': 1,
#  'attack2.adv': 4,
#  'attack2.base': 8,
#  'attack2.dis': 1,
#  'attack2.dmg': 8,
#  'attack2adv': 2,
#  'attack2dam': 1,
#  'attack3': 1,
#  'attack3.adv': 1,
#  'attack3.base': 1,
#  'attack3.dmg': 1,
#  'attack4': 1,
#  'attack4.adv': 1,
#  'attack4.base': 1,
#  'attack4.dmg': 1,
#  'attackadv': 1,
#  'attackadv2': 1,
#  'attackarcher dmg': 1,
#  'attackav11': 3,
#  'attackb adv': 5,
#  'attackb base': 6,
#  'attackb dmg': 6,
#  'attackbl': 4,
#  'attackbonus adv': 1,
#  'attackbonus base': 2,
#  'attackbonus dmg': 2,
#  'attackbr': 2,
#  'attackers': 1,
#  'attackfangred dmg': 1,
#  'attackg': 2,
#  'attacking goblin': 2,
#  'attacking goblin offhand': 1,
#  'attacking nearest goblin': 1,
#  'attacking the lookout': 1,
#  'attacking vs power': 1,
#  'attackmagic base': 1,
#  'attackmagic dis': 1,
#  'attackoffhand': 1,
#  'attackr': 2,
#  'attacks': 3,
#  'attacks aimed at wes tn': 1,
#  'attacks m': 1,
#  'attackthefire': 1,
#  'attacl': 1,
#  'attak': 1,
#  'attaque arc': 2,
#  'attck': 3,
#  'attempt the ritual': 2,
#  'attempt to chew stick into intricate lock pick without stabbing himself in the roof of his mouth': 1,
#  'attempting to tail neve': 1,
#  'attend to dead': 1,
#  'attk': 3,
#  'attrack  strength': 2,
#  'attributes': 1,
#  'audi  o': 5,
#  'audi  o nh': 1,
#  'audi  o nh   xxx': 1,
#  'audi  o per': 1,
#  'audio nh': 1,
#  'audição 14': 1,
#  'audição 15': 1,
#  'audição 17': 2,
#  'audição para ouvir dentro da casa 17': 1,
#  'auf': 2,
#  'augmented customs': 1,
#  'auto controle nh': 1,
#  'auto reroll': 2,
#  'autocontrole': 1,
#  'autocrit': 1,
#  'automatic cannon': 1,
#  'automatic cannon attack on creature attached to the morningstar': 1,
#  'automatic cannon target': 2,
#  'av10': 1,
#  'av10-1': 1,
#  'avantage': 1,
#  'avd': 1,
#  'avenger heal thyself cure wounds': 1,
#  'avoid cannon fire advantage bs': 1,
#  'avoid cannon fire vs': 1,
#  'avoid damage athletic graceful': 1,
#  'avoid gunfire': 1,
#  'avoid lock on vs': 1,
#  'avoid tail': 1,
#  'avoid tailing': 1,
#  'avoid turret fire w  mobility': 1,
#  'avoid turret fire with advantage vs': 1,
#  'avoiding the chasing ship': 1,
#  'avrien': 1,
#  'awaken': 1,
#  'awareness': 9,
#  'awareness    d': 1,
#  'awareness  keen eyed': 1,
#  'awareness leofric': 1,
#  'awareness to overcome': 1,
#  'awareness to stop': 1,
#  'awarness': 3,
#  'awe 1 bonus die': 1,
#  'awe bonus die': 1,
#  'awe questioning': 1,
#  'awereness': 1,
#  'axe': 32,
#  'axe   maw d': 1,
#  'axe   two': 1,
#  'axe 1': 1,
#  'axe 2': 1,
#  'axe attack': 1,
#  'axe attack  if alive': 2,
#  'axe called shot': 1,
#  'axe chop': 1,
#  'axe damage': 2,
#  'axe feat dice': 1,
#  'axe slimey': 1,
#  'axeman door breaky': 1,
#  'axes': 5,
#  'axes    hope': 1,
#  'azaka initiative': 1,
#  'b': 3,
#  'b  bow': 5,
#  'b  dex save': 1,
#  'b  protection': 2,
#  'b  spear': 6,
#  'b att': 2,
#  'b con': 1,
#  'b dam': 2,
#  'b hd': 1,
#  'b init': 1,
#  'ba two weapon': 1,
#  'babap': 1,
#  'back kick': 4,
#  'back on suit': 1,
#  'background': 5,
#  'background environment': 1,
#  'background vow': 1,
#  'backhand': 1,
#  'backstab': 3,
#  'backswing': 1,
#  'bad  luck': 1,
#  'bad habit': 4,
#  'badass check': 1,
#  'badgerwissave': 1,
#  "bag o'tricks": 1,
#  'bag of tricks': 2,
#  'bait': 1,
#  'bait a trap': 2,
#  'baker quick': 2,
#  'balance  with ap': 1,
#  'balance check': 1,
#  'balance plus ap': 1,
#  'bald human in good health': 1,
#  'baldin': 1,
#  'baldor': 1,
#  'baldric con save': 1,
#  'baldric dex save': 1,
#  'baldric initiative': 6,
#  'baldric wis save': 1,
#  'ball': 6,
#  'ball   s tornado save': 2,
#  'ballistae': 5,
#  'ballistic skill': 3,
#  'balls to walls': 1,
#  'banashing arrow': 1,
#  'bandit': 5,
#  'bandit   athletics': 2,
#  'bandit   spear': 3,
#  'bandit   spear vs': 1,
#  'bandit   spear vs wes': 1,
#  'bandit  cinder': 2,
#  'bandit  dashiel': 1,
#  'bandit  earl': 2,
#  'bandit alton': 2,
#  'bandit aoo on anko': 1,
#  'bandit calithia': 2,
#  'bandit cavalry': 2,
#  'bandit con save': 1,
#  'bandit crossbow': 1,
#  'bandit crossbow flik': 1,
#  'bandit init': 1,
#  'bandit initiative': 3,
#  'bandit intimidation': 1,
#  'bandit magdala': 1,
#  'bandit magdela': 1,
#  'bandit redplume': 12,
#  'bandit relion': 1,
#  'bandit save': 3,
#  'bandit tatiana': 1,
#  'bandits': 1,
#  'bandits initiative': 1,
#  'bane': 7,
#  'bane from charging': 1,
#  'banes': 19,
#  'bang bang kaiju': 1,
#  'banishment': 1,
#  'banog': 1,
#  'banzai centipede attacks': 1,
#  'banzai centipede chooses': 1,
#  'barbed': 1,
#  'barbs': 2,
#  'bardic inspiration': 2,
#  'bardic inspiration to medicine': 1,
#  'bargain  cha': 1,
#  'barlgura': 1,
#  'barlgura con save': 1,
#  'barlgura fist damage': 1,
#  'barlgura init': 1,
#  'barlgura strength': 1,
#  'barlgura wis': 1,
#  'barlguras': 1,
#  'barluras': 1,
#  'barrel initiative': 1,
#  'bars': 1,
#  'base': 10,
#  'base   occult domain with one difficulty': 1,
#  'base  pursuit skill': 1,
#  'base con save': 1,
#  'base damage': 2,
#  'base familiar hp': 1,
#  'base gold': 1,
#  'base occult domain     difficulty': 2,
#  'base roll': 1,
#  'base shot': 2,
#  'bash': 1,
#  'bat    vs': 2,
#  'bat around': 1,
#  'bat perception': 1,
#  'bat scouring': 1,
#  'bat ul': 1,
#  'bate papo elvis': 1,
#  'bate papo robinho': 1,
#  'batlike things': 1,
#  'battle': 105,
#  'battle   tn': 1,
#  'battle  find the right place': 1,
#  'battle  tn': 1,
#  'battle axe': 6,
#  'battle axe   froggie': 1,
#  'battle feat': 1,
#  'battle for directing the soldiers': 1,
#  'battle tn': 2,
#  'battle wounds': 1,
#  'battleaxe': 25,
#  'battleaxe   creature': 2,
#  'battleaxe   larrakh': 1,
#  'battleaxe   like': 1,
#  'battleaxe   spiderman': 1,
#  'battleaxe froggo': 2,
#  'battleaxe grabby': 1,
#  'battleaxe kermit': 1,
#  'battleaxe leader': 2,
#  'battleaxe spell frog': 1,
#  'battleaxe swordsman': 1,
#  'battleaxe toasty': 1,
#  'battles': 1,
#  'battlescars': 1,
#  'bb dex save': 1,
#  'bb dex save dis': 1,
#  'be lucky': 1,
#  'be normalheart': 1,
#  'be the monster': 1,
#  'beak': 7,
#  'beak gaden': 2,
#  'beak tally': 1,
#  'bear damage if defense roll fails': 1,
#  'bear dex save': 1,
#  'bear init': 1,
#  'bear initiative': 1,
#  'bear v door': 1,
#  'bear vs carvings': 1,
#  'bear vs door': 1,
#  'beast': 2,
#  'beast chart 1': 1,
#  'beast chart 2': 1,
#  'beast claw': 1,
#  'beast dex save': 1,
#  'beast disbelieve': 1,
#  ...}

# %%
# Total set
bar_graphic(dicionario = total_pps_dict, max=20)

# %%
# CR Set
CR_pps_dict = CR_pps.to_dict()
bar_graphic(dicionario=CR_pps_dict, paleta="mako", max=18)

# %%
# Podcast set
podcast_pps_dict = podcast_pps.to_dict()
bar_graphic(dicionario = podcast_pps_dict, paleta="mako")

# %%
# Skills Set
skills_pps_dict = skills_pps.to_dict()
bar_graphic(dicionario = skills_pps_dict, paleta="mako")

# %% [markdown]
# # Total de Palavras do backward_text

# %%
# Transforma cada linha da coluna de frases do dataframe em lista cujos elementos 
# são as frases
list_df = list(concatenated_df["backward_text"])
# Separa a lista de frases em uma lista de lista de palavras
full_list = [i.split(" ") for i in list_df]
full_list
# Out:
# [['going',
#   'weekly',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'experimental',
#   'arcs',
#   '[',
#   'Woohoo!]',
#   'starting',
#   'this',
#   'week.',
#   'So,',
#   'um,',
#   'I',
#   'guess',
#   'actually',
#   'we',
#   'have',
#   'an',
#   'episode—',
#   'I',
#   'hope',
#   'we',
#   'don’t',
#   'screw',
#   'it',
#   'up!'],
#  ['by,',
#   'like,',
#   'logic,',
#   'you',
#   'know',
#   'what',
#   'I',
#   'mean?',
#   'So',
#   'I',
#   'can’t',
#   'be',
#   'like,',
#   '“I',
#   'wanna',
#   'Help',
#   'Out',
#   'by…”',
#   '[inhaling',
#   'sharply',
#   'through',
#   'teeth]',
#   'Ssssssssssssss...',
#   'Ooooh,',
#   'logic.',
#   '“...pulling',
#   'the',
#   'sun',
#   'down.”',
#   'Yeah.'],
#  ['success,',
#   'you',
#   'open',
#   'yourself',
#   'up',
#   'to',
#   'repercussions.',
#   'To,',
#   'like,',
#   'the',
#   'same',
#   'reper—',
#   'so',
#   'you',
#   'can',
#   'help',
#   'out,',
#   'yeah,',
#   'but',
#   'you',
#   'are',
#   'also',
#   'exposing',
#   'yourself',
#   'to',
#   'danger,',
#   'which',
#   'is',
#   'real',
#   'smart.'],
#  ['success,',
#   'you',
#   'open',
#   'yourself',
#   'up',
#   'to',
#   'repercussions.',
#   'To,',
#   'like,',
#   'the',
#   'same',
#   'reper—',
#   'so',
#   'you',
#   'can',
#   'help',
#   'out,',
#   'yeah,',
#   'but',
#   'you',
#   'are',
#   'also',
#   'exposing',
#   'yourself',
#   'to',
#   'danger,',
#   'which',
#   'is',
#   'real',
#   'smart.'],
#  ['play',
#   'in',
#   'the',
#   'NFL!”',
#   'and',
#   'he',
#   'was',
#   'like',
#   '“No.”',
#   'There’s',
#   'some',
#   'really-',
#   'we',
#   'haven’t—',
#   'I',
#   'really',
#   'like',
#   'this',
#   'idea',
#   'of',
#   'a',
#   'Chosen',
#   'that’s',
#   'just',
#   'like',
#   '[crosstalk]',
#   '“No,',
#   'no',
#   'thank',
#   'you!”'],
#  ['you',
#   'are',
#   'dealing',
#   'with',
#   'the',
#   'consequences',
#   'of',
#   'your',
#   'own',
#   'spellcasting.',
#   'That’s',
#   'definitely',
#   'this.',
#   'Um.',
#   'Yeah',
#   'so-',
#   'but',
#   'if',
#   'it’s',
#   'Weird,',
#   'I',
#   'rolled',
#   'an',
#   'eight',
#   'plus',
#   'two',
#   'so',
#   'it’s',
#   'a',
#   '10.'],
#  ['booze',
#   'in',
#   'a',
#   'Arnold',
#   'Palmer.',
#   'I',
#   'mean,',
#   'sometimes',
#   'there',
#   'is.',
#   'Arnold',
#   'Palmer',
#   'loves',
#   'to',
#   'party.',
#   '[',
#   'and',
#   'laugh]',
#   "That's",
#   'true,',
#   'yeah.',
#   '[chuckles]',
#   'Sometimes',
#   'there',
#   'is',
#   'booze',
#   'in',
#   'an',
#   'Arnold.',
#   '[Laughter]'],
#  ['no.',
#   'Yeah,',
#   'so',
#   'go',
#   'ahead',
#   'and',
#   'mark',
#   'experience.',
#   'Yes,',
#   'but',
#   "don't",
#   'you',
#   'see?',
#   'I',
#   "don't",
#   'want',
#   'to',
#   'have',
#   'failed.',
#   '[crosstalk]',
#   'Did',
#   'you',
#   'think',
#   'about',
#   'it',
#   'that',
#   'way?',
#   '[crosstalk]',
#   'Mmm,',
#   'interesting.'],
#  ['he’s',
#   'kind',
#   'of',
#   'leaning',
#   'backwards,',
#   'shooting',
#   'at',
#   'the',
#   'snake',
#   'along',
#   'the',
#   'length',
#   'of',
#   'its',
#   'watery',
#   'body,',
#   'and',
#   'basically',
#   'heading',
#   'towards',
#   'one',
#   'of',
#   'the',
#   'big',
#   'water',
#   'slides,',
#   'just',
#   'away',
#   'from',
#   'them.'],
#  ['I',
#   'just',
#   'think',
#   'it’s',
#   'information',
#   'we',
#   'need.',
#   '’s',
#   'gonna',
#   'Investigate',
#   'a',
#   'Mystery.',
#   'Ok.',
#   'And…',
#   'Roll',
#   'plus',
#   'Sharp.',
#   '[',
#   'rolls]',
#   'That’s',
#   'very',
#   'bad.',
#   '[quietly]',
#   'Shit.',
#   'You',
#   'did',
#   'a',
#   'bad',
#   'job,',
#   'Dad.'],
#  ['trying',
#   'to',
#   'wait',
#   'this',
#   'thing',
#   'out--',
#   'Yeah,',
#   'I',
#   'think',
#   'hiding',
#   'is',
#   'a',
#   'wonderful',
#   'choice;',
#   'this',
#   'is',
#   'the',
#   'choice',
#   'to',
#   'make.',
#   'Is',
#   'there',
#   'a',
#   'Hide',
#   'Under',
#   'Pressure?',
#   '[laughing]',
#   'Hide',
#   'Under',
#   'Bed?'],
#  ['Yeah,',
#   'I',
#   'love',
#   'it.',
#   'Mark',
#   'Luck,',
#   'and',
#   'you',
#   'have',
#   'spent',
#   'one',
#   'Luck.',
#   'Hey,',
#   'and',
#   'I',
#   'wanna',
#   'do',
#   'a',
#   'cool',
#   'line.',
#   'Yeah,',
#   'yeah,',
#   'do',
#   'a',
#   'cool',
#   'line.',
#   'Aubrey',
#   'Fuego,',
#   'ya',
#   'bastard!'],
#  ['Just',
#   'another',
#   'one',
#   'of',
#   'the',
#   'many',
#   'services',
#   'we',
#   'offer',
#   'from',
#   'the',
#   'Forestry',
#   'Service.',
#   'Swimmer',
#   'Is',
#   'clothes—',
#   'Oh!',
#   'Okay,',
#   'I’m',
#   'going,',
#   'I’m',
#   'going,',
#   'I’m',
#   'going!',
#   'Duck',
#   'Go!',
#   'Go!',
#   'Go!',
#   'Go!',
#   'Go!'],
#  ['rites',
#   'of',
#   'Omec,',
#   'and',
#   'you',
#   'and',
#   'your',
#   'companions,',
#   'that’s',
#   'you',
#   'guys,',
#   'can',
#   'expect',
#   'to',
#   'receive',
#   'free',
#   'healing',
#   'and',
#   'care',
#   'at',
#   'a',
#   'temple,',
#   'shrine,',
#   'or',
#   'other',
#   'established',
#   'presence',
#   'of',
#   'Omec’s',
#   'faith.'],
#  ['impotent',
#   'rage.',
#   'No,',
#   'he',
#   'wants,',
#   'uh',
#   '-',
#   'And',
#   'a',
#   'two',
#   'minute',
#   'song.',
#   'He',
#   'was',
#   'thinking',
#   'more',
#   'along',
#   'the',
#   'lines',
#   'of',
#   'slaying,',
#   'protecting,',
#   'guidance',
#   '-',
#   'Ah.',
#   'Got',
#   'it.',
#   'Adventuring,',
#   'essentially.',
#   'Excellent.'],
#  ['offered',
#   'you',
#   'a',
#   '-',
#   '10',
#   'gold',
#   'pieces',
#   'apiece.',
#   'and',
#   'Each?',
#   'Each,',
#   'yes.',
#   'Nice.',
#   'Which,',
#   'um,',
#   'I',
#   'mean,',
#   "I'm",
#   'not',
#   'your',
#   'boss,',
#   'but',
#   "that's",
#   'not',
#   'a',
#   'lot',
#   'of',
#   'money.',
#   'But',
#   'hey-'],
#  ['on',
#   'the',
#   'coast.',
#   "You've",
#   'taken',
#   'the',
#   'off-ramp,',
#   'uh,',
#   'that',
#   'will',
#   'lead',
#   'you',
#   'to',
#   'Phandalin,',
#   'and',
#   'things',
#   'definitely',
#   'are',
#   'not',
#   'as',
#   'well',
#   'maintained.',
#   'Lot',
#   'of',
#   'potholes.',
#   "Don't",
#   'worry,',
#   'I',
#   'got',
#   'this.'],
#  ['Merle?',
#   '[dice',
#   'rolling]',
#   'Pshew.',
#   'Wow.',
#   'Uh...',
#   '6.',
#   'And',
#   "what'd",
#   'you',
#   'get,',
#   '?',
#   'I',
#   'got',
#   'a',
#   'crit',
#   '20,',
#   'so',
#   'that’s',
#   '23?',
#   '23.',
#   'Okay.',
#   'You',
#   'see',
#   'the',
#   'shit',
#   'out',
#   'of',
#   'everything.',
#   'Mhm.'],
#  ['to',
#   'a',
#   'stop,',
#   'about',
#   'two-hundred',
#   'feet',
#   'out-',
#   'And',
#   'I',
#   'motion',
#   'silently,',
#   'to',
#   'get',
#   'the',
#   'attention',
#   'of',
#   'Merle',
#   'and',
#   'Taako,',
#   'and',
#   'kinda',
#   'pull',
#   'them',
#   'up',
#   'towards',
#   'the',
#   'front',
#   'of',
#   'the',
#   'wagon.'],
#  ['is',
#   'where,',
#   "who's",
#   'fighting',
#   'whom...',
#   'so',
#   'yeah,',
#   'you',
#   'can',
#   'take',
#   'a',
#   'movement,',
#   'up',
#   'to',
#   'your',
#   'speed,',
#   'you',
#   'can-',
#   'Do',
#   'I',
#   'have',
#   'to',
#   'take',
#   'a',
#   'movement?',
#   'You',
#   'do',
#   'not,',
#   'no.',
#   'Okay.'],
#  ['using',
#   'an',
#   'object,',
#   'like,',
#   'maneuvering',
#   'a',
#   'complicated,',
#   'like,',
#   'device?',
#   'That',
#   'will',
#   'take',
#   'an',
#   'action.',
#   'It’s',
#   'kinda',
#   'up',
#   'to',
#   'my',
#   'discretion',
#   'what',
#   'does',
#   'and',
#   'doesn’t',
#   'take',
#   'up',
#   'an',
#   'action.',
#   'Okay,',
#   'I-'],
#  ['forty',
#   'feet',
#   'out.',
#   'Okay,',
#   'now,',
#   'question.',
#   'Yeah.',
#   'Do',
#   'I',
#   'see',
#   'the',
#   'one',
#   'in',
#   'the',
#   'brush?',
#   '…',
#   'Um…',
#   'You',
#   'actually',
#   'do',
#   'not?',
#   'is',
#   'the',
#   'one',
#   'who',
#   'spotted',
#   'him.',
#   'Oh',
#   'okay.',
#   'Um-'],
#  ['probably',
#   'about',
#   'fifteen',
#   'to',
#   'twenty',
#   'feet',
#   'away',
#   'from',
#   'you,',
#   'he’s',
#   'not',
#   'right',
#   'next',
#   'to',
#   'the',
#   'wagon',
#   'so',
#   'that’s',
#   'a,',
#   'that’s',
#   'a-',
#   'Well,',
#   'Magnus',
#   'has',
#   'a',
#   'vertical',
#   'leap',
#   'of',
#   'eighteen',
#   'feet.'],
#  ['just',
#   'barely,',
#   'you',
#   'throw',
#   'it',
#   'into',
#   'the',
#   'woods,',
#   'you',
#   'can’t',
#   'exactly',
#   'see-',
#   'you',
#   'see',
#   'like',
#   'a,',
#   'branches',
#   'rustling,',
#   'and',
#   'you',
#   'throw',
#   'your',
#   'axe',
#   'in',
#   'that',
#   'direction',
#   'and',
#   'you',
#   'hear,',
#   'Gerblin'],
#  ['just',
#   'barely,',
#   'you',
#   'throw',
#   'it',
#   'into',
#   'the',
#   'woods,',
#   'you',
#   'can’t',
#   'exactly',
#   'see-',
#   'you',
#   'see',
#   'like',
#   'a,',
#   'branches',
#   'rustling,',
#   'and',
#   'you',
#   'throw',
#   'your',
#   'axe',
#   'in',
#   'that',
#   'direction',
#   'and',
#   'you',
#   'hear,',
#   'Gerblin'],
#  ['just',
#   'barely,',
#   'you',
#   'throw',
#   'it',
#   'into',
#   'the',
#   'woods,',
#   'you',
#   'can’t',
#   'exactly',
#   'see-',
#   'you',
#   'see',
#   'like',
#   'a,',
#   'branches',
#   'rustling,',
#   'and',
#   'you',
#   'throw',
#   'your',
#   'axe',
#   'in',
#   'that',
#   'direction',
#   'and',
#   'you',
#   'hear,',
#   'Gerblin'],
#  ['just',
#   'barely,',
#   'you',
#   'throw',
#   'it',
#   'into',
#   'the',
#   'woods,',
#   'you',
#   'can’t',
#   'exactly',
#   'see-',
#   'you',
#   'see',
#   'like',
#   'a,',
#   'branches',
#   'rustling,',
#   'and',
#   'you',
#   'throw',
#   'your',
#   'axe',
#   'in',
#   'that',
#   'direction',
#   'and',
#   'you',
#   'hear,',
#   'Gerblin'],
#  ['we’re',
#   'here.',
#   'A',
#   'wave',
#   'of',
#   'bats-',
#   'Taako',
#   'Excellent.',
#   '-comes',
#   'pouring',
#   'out.',
#   'A',
#   'wave',
#   'of',
#   'gas?',
#   'Bats.',
#   'Bats.',
#   'Bats.',
#   'Bats.',
#   'Baseball',
#   'bats.',
#   'Do',
#   'the',
#   'bats',
#   'have',
#   'gas?',
#   'They',
#   'definitely',
#   'do,',
#   'yeah.'],
#  ['draw',
#   'closer',
#   'to',
#   'them,',
#   'they',
#   'seem',
#   'more',
#   'agitated.',
#   'Couple',
#   'of',
#   'them',
#   'are',
#   'snarling',
#   'at',
#   'you',
#   'now.',
#   'Uh,',
#   'they',
#   'are-',
#   'But',
#   'there’s',
#   'nothing',
#   'else',
#   'in',
#   'the',
#   'room',
#   'other',
#   'than',
#   'these',
#   'wolves?'],
#  ['‘so',
#   'there’s',
#   'some',
#   'wolves',
#   'down',
#   'there,',
#   'it',
#   'doesn’t',
#   'seem',
#   'like',
#   'it’s',
#   'worth',
#   'it,',
#   'let’s',
#   'keep',
#   'going.’',
#   'Taako',
#   'Excellent,',
#   'well,',
#   'I',
#   'trust',
#   'your',
#   'judgement.',
#   'Okay,',
#   'I’m',
#   'into',
#   'that.',
#   'Off',
#   'we',
#   'go.'],
#  ['can-',
#   'Alright,',
#   'I',
#   'will',
#   'climb',
#   '-',
#   'I,',
#   'I',
#   'will',
#   'climb.',
#   'What',
#   'do',
#   'I',
#   'need',
#   'to',
#   'do?',
#   'Uh,',
#   'you',
#   'will',
#   'make',
#   'a-',
#   'I’m',
#   'gonna',
#   'try',
#   'to',
#   'climb',
#   'up,',
#   'to',
#   'the',
#   'overpass.'],
#  ['the',
#   'bridge',
#   'is',
#   'relatively',
#   'rickety,',
#   'it’s',
#   'of',
#   'gerblin,',
#   'uh,',
#   'construction,',
#   'so',
#   'it’s',
#   'not',
#   'amazing,',
#   'but',
#   'it',
#   'looks',
#   'like',
#   'it’ll',
#   'hold',
#   'your',
#   'weight.',
#   'Okay.',
#   'So',
#   'I',
#   'roll',
#   'a',
#   '20',
#   'sided',
#   'die?'],
#  ['it',
#   'looks',
#   'like',
#   'it’ll',
#   'hold',
#   'your',
#   'weight.',
#   'Okay.',
#   'So',
#   'I',
#   'roll',
#   'a',
#   '20',
#   'sided',
#   'die?',
#   'You',
#   'roll',
#   'a',
#   '20',
#   'sided',
#   'die,',
#   'and',
#   'you',
#   'add',
#   'your,',
#   'uh,',
#   'your',
#   'Athletics.',
#   '[dice',
#   'roll]'],
#  ['does',
#   'that',
#   'sound',
#   'funny?',
#   '[talking',
#   'at',
#   'the',
#   'same',
#   'time',
#   'as',
#   ']',
#   'Because',
#   'of',
#   'the',
#   'character!',
#   '[talking',
#   'at',
#   'the',
#   'same',
#   'time',
#   'as',
#   ']',
#   'Because',
#   'of',
#   'the',
#   'racism?',
#   '[laughter]',
#   'There’s',
#   'no',
#   'racism!'],
#  ['-',
#   'Taako',
#   'Yeah,',
#   "I'll",
#   'be',
#   '-',
#   "It'll",
#   'be',
#   'better',
#   'by',
#   'myself.',
#   '[talking',
#   'over',
#   'Taako]',
#   'Well',
#   'yeah,',
#   'because',
#   'if',
#   "we're",
#   'trying',
#   'to',
#   'be',
#   'stealthy,',
#   "it's",
#   'always',
#   'better',
#   'to',
#   'have',
#   'smaller',
#   'numbers.'],
#  ['-',
#   'Taako',
#   'Yeah,',
#   "I'll",
#   'be',
#   '-',
#   "It'll",
#   'be',
#   'better',
#   'by',
#   'myself.',
#   '[talking',
#   'over',
#   'Taako]',
#   'Well',
#   'yeah,',
#   'because',
#   'if',
#   "we're",
#   'trying',
#   'to',
#   'be',
#   'stealthy,',
#   "it's",
#   'always',
#   'better',
#   'to',
#   'have',
#   'smaller',
#   'numbers.'],
#  ['-',
#   'Taako',
#   'Yeah,',
#   "I'll",
#   'be',
#   '-',
#   "It'll",
#   'be',
#   'better',
#   'by',
#   'myself.',
#   '[talking',
#   'over',
#   'Taako]',
#   'Well',
#   'yeah,',
#   'because',
#   'if',
#   "we're",
#   'trying',
#   'to',
#   'be',
#   'stealthy,',
#   "it's",
#   'always',
#   'better',
#   'to',
#   'have',
#   'smaller',
#   'numbers.'],
#  ['character',
#   'that',
#   'you',
#   "don't",
#   'know',
#   'is',
#   'there,',
#   'but',
#   'Taako',
#   'does.',
#   'Okay.',
#   'Gotcha.',
#   "I'll",
#   'wave',
#   'them',
#   'over.',
#   'Okay.',
#   'They',
#   'are',
#   'going',
#   'to,',
#   'uh',
#   '-',
#   '[talking',
#   'over',
#   ']',
#   "We're",
#   'not',
#   'so',
#   'stealthy!'],
#  ['than',
#   'McElroy.',
#   'Is',
#   'it',
#   'my',
#   'turn',
#   'yet?',
#   'Uh,',
#   'it',
#   'is',
#   "Magnus's",
#   'turn.',
#   "We're",
#   'to',
#   'the',
#   'top',
#   'of',
#   'the',
#   'order',
#   'now.',
#   'Can',
#   'you',
#   'ask',
#   'him',
#   'to',
#   'call',
#   'off',
#   'the',
#   'wolves?',
#   '[pause]'],
#  ['off',
#   'the',
#   'wolves?',
#   '[pause]',
#   'Can',
#   'I',
#   'roll',
#   'a',
#   'quick',
#   'Animal',
#   'Handling',
#   'check',
#   'to',
#   'see',
#   'if',
#   "there's",
#   'any',
#   'possibility',
#   'of',
#   'like,',
#   'controlling',
#   'the',
#   'wol',
#   '-',
#   'like,',
#   '[chuckling]',
#   'befriending',
#   'my',
#   'animal',
#   'friends?'],
#  ["shouldn't",
#   'say',
#   'the',
#   'sentence',
#   'out',
#   'loud,',
#   '“Yahweh',
#   'is',
#   'dead.”',
#   '[laughter]',
#   '[muffled]',
#   'Now',
#   'hold',
#   'on',
#   '-',
#   '[talking',
#   'over',
#   ']',
#   'Just',
#   'for',
#   'future',
#   'reference,',
#   'we',
#   'should',
#   'avoid',
#   'saying',
#   'that',
#   'sentence',
#   'out',
#   'loud.'],
#  ['Uh,',
#   "here's",
#   'some',
#   'flavor.',
#   'You',
#   'killed',
#   'him',
#   'and',
#   'you',
#   "didn't",
#   'even',
#   'think',
#   'twice',
#   'about',
#   'it.',
#   'You',
#   'just',
#   'did',
#   'it,',
#   'impulsively.',
#   'You',
#   'murdered',
#   'another',
#   'gerblin.',
#   "You're",
#   '-',
#   "you're",
#   'deeply',
#   'broken',
#   'inside.'],
#  ['upset,',
#   'but',
#   'the',
#   '-',
#   'Merle',
#   '[babytalking]',
#   'Aww,',
#   'come',
#   'here',
#   'Ruby!',
#   'Come',
#   'here',
#   '-',
#   'Uh,',
#   'she',
#   'bites',
#   'all',
#   'of',
#   'your',
#   'hand',
#   'off.',
#   '[',
#   'laughing]',
#   'Oh,',
#   'that’s',
#   'alright,',
#   'I',
#   'don’t',
#   'care',
#   '-'],
#  ['on',
#   'Saturday',
#   'Night',
#   'Live.',
#   'I',
#   'would',
#   'like',
#   'to',
#   '-',
#   'can',
#   'we',
#   '-',
#   'That',
#   'show',
#   'hasn’t',
#   'been',
#   'invented',
#   'yet.',
#   'Oh.',
#   'Or,',
#   'has',
#   'it',
#   'already',
#   'happened?',
#   'Oh',
#   'shit,',
#   'future',
#   '-',
#   'future',
#   'fantasy.'],
#  ['on',
#   'him',
#   'a',
#   'pair',
#   'of',
#   '-',
#   'I',
#   'do',
#   'it',
#   'covertly',
#   'so',
#   'the',
#   'other',
#   'guys',
#   'don’t',
#   'see.',
#   '[laughing]',
#   'Okay.',
#   'Make',
#   'a',
#   'st',
#   '-',
#   'make',
#   'a',
#   'stealth',
#   '-',
#   'Hey!',
#   'That’s',
#   'my',
#   'cousin!'],
#  ['culture,',
#   'it’s',
#   'a',
#   'blessing',
#   'that',
#   'we',
#   'do',
#   'for',
#   'the',
#   'dead,',
#   '(laughter)',
#   'that',
#   'we',
#   'help',
#   'to',
#   '-',
#   'I’d',
#   'like',
#   'to',
#   'roll',
#   'against',
#   'this',
#   'roll--',
#   'Help',
#   'to',
#   'usher',
#   'them',
#   'into',
#   'the',
#   'next...world.'],
#  ['culture,',
#   'it’s',
#   'a',
#   'blessing',
#   'that',
#   'we',
#   'do',
#   'for',
#   'the',
#   'dead,',
#   '(laughter)',
#   'that',
#   'we',
#   'help',
#   'to',
#   '-',
#   'I’d',
#   'like',
#   'to',
#   'roll',
#   'against',
#   'this',
#   'roll--',
#   'Help',
#   'to',
#   'usher',
#   'them',
#   'into',
#   'the',
#   'next...world.'],
#  ['[',
#   'sighs',
#   'in',
#   'relief]',
#   'When',
#   'Merle’s',
#   'not',
#   'looking.',
#   '[laughing]',
#   'Mmkay.',
#   'Make',
#   'a',
#   'sleight',
#   'of',
#   '-',
#   '[laughing]',
#   'Just',
#   'like,',
#   'slip',
#   'it',
#   '-',
#   'wooop',
#   '-',
#   'Merle',
#   'Hey',
#   'guys,',
#   'what’s',
#   '-',
#   'whatcha',
#   'doin’?'],
#  ['slip',
#   'it',
#   '-',
#   'wooop',
#   '-',
#   'Merle',
#   'Hey',
#   'guys,',
#   'what’s',
#   '-',
#   'whatcha',
#   'doin’?',
#   '[laughing]',
#   'Make',
#   'another',
#   'sleight',
#   'of',
#   'hand',
#   'check',
#   'for',
#   'me.',
#   'Merle',
#   'Gosh,',
#   'what',
#   '-',
#   'what’s',
#   'goin’',
#   'on',
#   'over',
#   'there?'],
#  ['slip',
#   'it',
#   '-',
#   'wooop',
#   '-',
#   'Merle',
#   'Hey',
#   'guys,',
#   'what’s',
#   '-',
#   'whatcha',
#   'doin’?',
#   '[laughing]',
#   'Make',
#   'another',
#   'sleight',
#   'of',
#   'hand',
#   'check',
#   'for',
#   'me.',
#   'Merle',
#   'Gosh,',
#   'what',
#   '-',
#   'what’s',
#   'goin’',
#   'on',
#   'over',
#   'there?'],
#  ['say',
#   'it’s',
#   'about',
#   'twenty',
#   'feet',
#   'down.',
#   'And',
#   'then',
#   'at',
#   'the',
#   'bottom',
#   'of',
#   'the',
#   'pit,',
#   'uh,',
#   'is',
#   'a',
#   'tunnel',
#   'leading',
#   'into',
#   'the',
#   'cave.',
#   'Let’s',
#   'go',
#   'in',
#   'the',
#   'pit!',
#   'Let’s',
#   'pit',
#   'it!'],
#  ['jump',
#   'down.',
#   'Okay,',
#   'cool.',
#   'I',
#   'just',
#   'did',
#   'that',
#   'thing',
#   '-',
#   'you',
#   'could',
#   'do',
#   'that',
#   'thing',
#   'I',
#   'did.',
#   'Well,',
#   'my',
#   'athletics',
#   'is',
#   'higher.',
#   'If',
#   'I',
#   'can',
#   'get',
#   'down',
#   'there',
#   'first',
#   '-'],
#  ['spring.',
#   'Do',
#   'any',
#   'of',
#   'you',
#   'have',
#   'a',
#   'nature',
#   'skill?',
#   'Could',
#   'you',
#   'check',
#   'out',
#   'those',
#   'mushrooms,',
#   'see',
#   'if',
#   'you',
#   'know',
#   'anything',
#   'about',
#   'them?',
#   '&',
#   'Hmm….',
#   'Uh,',
#   'yes,',
#   'I’m',
#   '+3',
#   'for',
#   'nature!'],
#  ['out',
#   'those',
#   'mushrooms,',
#   'see',
#   'if',
#   'you',
#   'know',
#   'anything',
#   'about',
#   'them?',
#   '&',
#   'Hmm….',
#   'Uh,',
#   'yes,',
#   'I’m',
#   '+3',
#   'for',
#   'nature!',
#   'Okay.',
#   'You',
#   'can',
#   'make',
#   'a',
#   'nature',
#   'check',
#   'if',
#   'you',
#   'want.',
#   'Uh.',
#   'Taako'],
#  ['about',
#   'them?',
#   '&',
#   'Hmm….',
#   'Uh,',
#   'yes,',
#   'I’m',
#   '+3',
#   'for',
#   'nature!',
#   'Okay.',
#   'You',
#   'can',
#   'make',
#   'a',
#   'nature',
#   'check',
#   'if',
#   'you',
#   'want.',
#   'Uh.',
#   'Taako',
#   'I’d',
#   'like',
#   'to',
#   'make',
#   'a',
#   'nature',
#   'check.',
#   'Mmkay.'],
#  ['passive',
#   'is,',
#   'uhh…',
#   'Mine’s',
#   '3.',
#   'No,',
#   'your',
#   'passive',
#   'perception',
#   'would',
#   'be...I',
#   'think',
#   'it’s',
#   'ten',
#   '-',
#   'ten',
#   'plus',
#   'your',
#   '-',
#   'your',
#   'perception',
#   'modifier.',
#   'Then',
#   'mine’s',
#   'thirteen.',
#   'Thirteen.',
#   '?',
#   'Mine',
#   'is',
#   'nine.'],
#  ['you',
#   'just',
#   'sort',
#   'of',
#   'hear',
#   'the',
#   'sound',
#   'of...',
#   'of',
#   'gooshing',
#   'above',
#   'you.',
#   'Well,',
#   'another',
#   'successful',
#   'battle.',
#   '[laughter]',
#   'Uhh..',
#   'Actually,',
#   'you’re',
#   'still',
#   'in',
#   'order!',
#   'Uh,',
#   'next',
#   'in',
#   'the',
#   'order',
#   'is',
#   'Taako.'],
#  ['to',
#   'gather',
#   'up...',
#   'the',
#   'fungus',
#   'for',
#   'future',
#   'use?',
#   'Uh,',
#   'if',
#   'you',
#   'wanna',
#   'try',
#   'and,',
#   'and',
#   'pick',
#   'some',
#   'of',
#   'the',
#   'fungus',
#   'I’ll--',
#   'No,',
#   'it’s',
#   'the',
#   'poison!',
#   'Hold',
#   'on',
#   'Magnus',
#   'Merle',
#   '-'],
#  ['of',
#   'the',
#   'fungus',
#   'I’ll--',
#   'No,',
#   'it’s',
#   'the',
#   'poison!',
#   'Hold',
#   'on',
#   'Magnus',
#   'Merle',
#   '-',
#   'I’ll',
#   'let',
#   'you',
#   'do',
#   'it',
#   'with',
#   'a',
#   'nature',
#   'check',
#   'if',
#   'you',
#   'want.',
#   'What’s',
#   'an',
#   'age',
#   'check?',
#   'Nature.'],
#  ['fungus',
#   'I’ll--',
#   'No,',
#   'it’s',
#   'the',
#   'poison!',
#   'Hold',
#   'on',
#   'Magnus',
#   'Merle',
#   '-',
#   'I’ll',
#   'let',
#   'you',
#   'do',
#   'it',
#   'with',
#   'a',
#   'nature',
#   'check',
#   'if',
#   'you',
#   'want.',
#   'What’s',
#   'an',
#   'age',
#   'check?',
#   'Nature.',
#   'Nature',
#   'check.'],
#  ['-',
#   'it',
#   'is,',
#   'uh,',
#   'decidedly,',
#   'uh,',
#   'taken',
#   'care',
#   'of.',
#   '[',
#   'triumphantly',
#   'laughs]',
#   'Kudos',
#   'all',
#   'around,',
#   'gentlemen.',
#   'Yeah',
#   'that',
#   'was',
#   'a',
#   '-',
#   'that',
#   'was',
#   'a',
#   'very',
#   'quick',
#   'uh,',
#   'quick',
#   'grinder',
#   'battle.'],
#  ['grinder',
#   'battle.',
#   'But,',
#   'uh,',
#   'I',
#   'wanna',
#   'make',
#   'a',
#   'perception',
#   'check',
#   '-',
#   'The',
#   'orc',
#   'woman',
#   'leans',
#   'back',
#   'in',
#   'to',
#   'go',
#   '“I',
#   'was',
#   'like',
#   '-',
#   'Oh,',
#   'shit.”',
#   'Orc',
#   'Woman',
#   'Oh',
#   'shit,',
#   'okay.'],
#  ['grinder',
#   'battle.',
#   'But,',
#   'uh,',
#   'I',
#   'wanna',
#   'make',
#   'a',
#   'perception',
#   'check',
#   '-',
#   'The',
#   'orc',
#   'woman',
#   'leans',
#   'back',
#   'in',
#   'to',
#   'go',
#   '“I',
#   'was',
#   'like',
#   '-',
#   'Oh,',
#   'shit.”',
#   'Orc',
#   'Woman',
#   'Oh',
#   'shit,',
#   'okay.'],
#  ['uh,',
#   'what’s',
#   'your',
#   'Christian',
#   'name?',
#   'What,',
#   'what',
#   'were',
#   'you,',
#   'your',
#   'born',
#   'name',
#   '-',
#   'I,',
#   'uh',
#   '-',
#   'Black',
#   'Spider',
#   'sounds',
#   'formal.',
#   'Black',
#   'Spider',
#   'It’s',
#   'not',
#   'very',
#   'serious,',
#   'is',
#   'it?',
#   '[',
#   'chuckles]'],
#  ['uh,',
#   'what’s',
#   'your',
#   'Christian',
#   'name?',
#   'What,',
#   'what',
#   'were',
#   'you,',
#   'your',
#   'born',
#   'name',
#   '-',
#   'I,',
#   'uh',
#   '-',
#   'Black',
#   'Spider',
#   'sounds',
#   'formal.',
#   'Black',
#   'Spider',
#   'It’s',
#   'not',
#   'very',
#   'serious,',
#   'is',
#   'it?',
#   '[',
#   'chuckles]'],
#  ['sounds',
#   'formal.',
#   'Black',
#   'Spider',
#   'It’s',
#   'not',
#   'very',
#   'serious,',
#   'is',
#   'it?',
#   '[',
#   'chuckles]',
#   'Uh,',
#   '‘kay,',
#   'do',
#   'you',
#   'have',
#   'a,',
#   'uh,',
#   'check',
#   '-',
#   'a',
#   'Persuasion',
#   'check,',
#   'a,',
#   'uh,',
#   'do',
#   'a',
#   'Persuasion',
#   'check.'],
#  ['door',
#   'I',
#   'guess.',
#   'Uh,',
#   'so',
#   'is',
#   'the',
#   'spider',
#   'up',
#   'now',
#   'or',
#   'am',
#   'I',
#   'up',
#   'now?',
#   'Uh,',
#   'sorry…',
#   'uh,',
#   'yeah,',
#   'it’s',
#   'Magnus.',
#   'Great.',
#   'I’m',
#   'gonna',
#   'jump',
#   'on',
#   'the,',
#   'uh,',
#   'spider’s',
#   'back.'],
#  ['leads',
#   'you',
#   'through',
#   'these',
#   'giant,',
#   'uh,',
#   'uh,',
#   'open',
#   'iron-wrought',
#   'doors',
#   'which',
#   'opens',
#   'up',
#   'into',
#   'a',
#   'large',
#   'chamber',
#   'where',
#   '-',
#   'where',
#   'uh,',
#   'uh',
#   '-',
#   'Renee',
#   'the',
#   'jackhammer-bot',
#   'was',
#   'being',
#   'stored.',
#   'Mhm.'],
#  ['figured',
#   'out',
#   'that',
#   'it’s',
#   'just',
#   '-',
#   'just',
#   'kind',
#   'of',
#   'a',
#   'robe.',
#   'Okay.',
#   'Is',
#   'there',
#   'any',
#   'kind',
#   'of',
#   'like',
#   'sense',
#   'magic',
#   'or',
#   'something',
#   'that',
#   'wizards',
#   'can',
#   'do?',
#   'I',
#   'have',
#   'sense',
#   'magic.'],
#  ['-',
#   'There’s',
#   'a',
#   'spell,',
#   'there’s',
#   'a',
#   '-',
#   'I',
#   'have',
#   'a',
#   'detect',
#   'magic',
#   'spell',
#   'but',
#   'I',
#   'don’t',
#   'really',
#   'wanna',
#   'do',
#   'it,',
#   'because',
#   'I',
#   'think',
#   'I',
#   'would',
#   'have',
#   'gotten',
#   'a',
#   'five',
#   '-'],
#  ['detect',
#   'magic',
#   'spell',
#   'but',
#   'I',
#   'don’t',
#   'really',
#   'wanna',
#   'do',
#   'it,',
#   'because',
#   'I',
#   'think',
#   'I',
#   'would',
#   'have',
#   'gotten',
#   'a',
#   'five',
#   '-',
#   'You',
#   'up-up-up!-also',
#   'have',
#   'an',
#   'arcana',
#   'check',
#   'that',
#   'you',
#   'can',
#   'make.'],
#  ['-',
#   'oh',
#   'my.',
#   'Probably',
#   'pretty',
#   'good.',
#   '[Short',
#   'pause]',
#   'Uhh,',
#   'I',
#   'got',
#   'a',
#   '1,',
#   'so',
#   'I',
#   'don’t',
#   'know',
#   'if',
#   'it’s',
#   '-',
#   'I',
#   'try',
#   'to',
#   'eat',
#   'it,',
#   'but',
#   'I',
#   'can’t.',
#   '[chuckles]',
#   'Okay.'],
#  ['it.',
#   'I',
#   'got',
#   'a',
#   '2.',
#   '[laughter]',
#   'What’s',
#   'your',
#   'plusses?',
#   'None',
#   'of',
#   'you',
#   'can',
#   'quite,',
#   'uh,',
#   'none',
#   'of',
#   'you',
#   'can',
#   'quite',
#   'figure',
#   'this',
#   'out.',
#   'Wait,',
#   'I’m',
#   'gonna',
#   'roll',
#   'now.',
#   'Hold',
#   'on.'],
#  ['Once',
#   'you’ve',
#   'found',
#   'your',
#   'voice',
#   'you',
#   'can',
#   'bring',
#   'it',
#   'to',
#   'the',
#   'table',
#   'but',
#   'this',
#   'is',
#   '-',
#   'this',
#   'is',
#   'not',
#   'workshop',
#   'time.',
#   'Do',
#   'I',
#   'see',
#   'anything',
#   'else',
#   'in',
#   'the',
#   'room?',
#   'No.'],
#  ['a',
#   'minute.',
#   'And',
#   'I’m',
#   'going',
#   'to',
#   'yell;',
#   'Merle',
#   'There’s',
#   'only',
#   'four',
#   'of',
#   '‘em!',
#   'Platoon…',
#   'One,',
#   'attack',
#   'from',
#   'the',
#   'east!',
#   'Platoon',
#   'Two,',
#   'attack',
#   'from',
#   'the',
#   'west!',
#   'Which',
#   'echoes,',
#   'down',
#   'the',
#   'hill.'],
#  ['[Rolls]',
#   'Yup!',
#   'You',
#   'said',
#   'an',
#   'intelligence',
#   'check?',
#   'They’re',
#   'making',
#   'an',
#   'intelligence',
#   'check',
#   'to',
#   'combat',
#   'your',
#   'intimidation.',
#   'Yeah',
#   'your',
#   'intimidation.',
#   'Oh,',
#   'okay.',
#   'Cause',
#   'you’re',
#   'lying',
#   'to',
#   'them',
#   'essentially.',
#   'Uhh,',
#   '9.',
#   'Okay.'],
#  ['intact.',
#   'Oh,',
#   'I',
#   'guess',
#   'we’ll',
#   '-',
#   'I’ll',
#   '-',
#   'let’s',
#   'head',
#   'into',
#   'the',
#   'bar,',
#   'see',
#   'what’s',
#   'going',
#   'on.',
#   'You',
#   'walk',
#   'towards',
#   'the',
#   'door',
#   'of',
#   'the',
#   'bar,',
#   'and,',
#   'um,',
#   'a',
#   'familiar',
#   '-'],
#  ['the',
#   'bar,',
#   'see',
#   'what’s',
#   'going',
#   'on.',
#   'You',
#   'walk',
#   'towards',
#   'the',
#   'door',
#   'of',
#   'the',
#   'bar,',
#   'and,',
#   'um,',
#   'a',
#   'familiar',
#   '-',
#   'Wait,',
#   'wait,',
#   'wait,',
#   'what',
#   'do',
#   'I',
#   'see',
#   'in',
#   'there?',
#   'Perception',
#   'check.'],
#  ['the',
#   'sound,',
#   'um.',
#   'You',
#   'hear',
#   'this',
#   'sound,',
#   'actually',
#   '-',
#   '[imitating',
#   'the',
#   'sound',
#   'of',
#   'an',
#   'arrow',
#   'flying',
#   'to',
#   'its',
#   'target',
#   'and',
#   'hitting]',
#   'sssssssshheew-THUNK.',
#   'Taako',
#   'Oh',
#   'no.',
#   'I',
#   'know',
#   'what',
#   'that',
#   'is.'],
#  ['get',
#   'everybody',
#   'up',
#   'out',
#   'of',
#   'the',
#   'well.',
#   'Including',
#   'Killian,',
#   'that’s',
#   'a',
#   'group',
#   'effort,',
#   'pulling',
#   'her',
#   'up,',
#   'she’s',
#   'a',
#   '-',
#   'she’s',
#   'a',
#   '-',
#   'I',
#   'mean',
#   'she’s',
#   'a',
#   'big',
#   'orc',
#   'woman.',
#   'Um.'],
#  ['it',
#   'looks',
#   'like.',
#   'A',
#   'feather',
#   'duster.',
#   'Well,',
#   'no.',
#   'It’s',
#   'an',
#   'enchanted',
#   'feather',
#   'duster',
#   'that,',
#   'uh,',
#   'is',
#   'imbued',
#   'with',
#   'charges',
#   'of',
#   'the',
#   'spell',
#   'Slow',
#   'Fall.',
#   'Okay,',
#   'great.',
#   'It’s',
#   'a',
#   'very',
#   'specific--'],
#  ['Sense',
#   'Mechanism.',
#   'You',
#   'don’t',
#   'have',
#   'that.',
#   'No',
#   'I',
#   'don’t.',
#   '[',
#   'and',
#   'laugh]',
#   'You',
#   'don’t',
#   'have',
#   '-',
#   'I',
#   'use',
#   'my',
#   'cheating',
#   'playing',
#   'cards',
#   'to',
#   'cheat',
#   'the',
#   'game',
#   'and',
#   'cast',
#   'Sense',
#   'Mechanism.'],
#  ['her',
#   'and',
#   'on',
#   'ourselves.',
#   'Why',
#   'do',
#   'you',
#   'think',
#   'that',
#   'she’s',
#   'learning',
#   'stuff',
#   'from',
#   'that?',
#   'Well',
#   'because',
#   'she’s',
#   'able',
#   '-',
#   'she',
#   'knows',
#   'about',
#   'the',
#   'gauntlet,',
#   'but',
#   'can’t',
#   'tell',
#   'us',
#   'about',
#   'it.'],
#  ['to',
#   'Taako',
#   'and',
#   'I',
#   'say,',
#   'Merle',
#   'It’ll',
#   'be',
#   'alright,',
#   'come',
#   'on.',
#   'Taako',
#   'I’m',
#   'scared.',
#   'Merle',
#   'Let’s',
#   'get',
#   'in',
#   'the',
#   'big',
#   'glass',
#   'ball.',
#   'Taako',
#   'Okay.',
#   'Merle',
#   '‘Kay.',
#   'It’ll',
#   'be',
#   'fun!',
#   'Taako'],
#  ['as',
#   'we',
#   'can',
#   'tell,',
#   'is',
#   'this',
#   'moon—',
#   'is',
#   'the',
#   'place',
#   'we’re',
#   'in,',
#   'like,',
#   'a',
#   'façade?',
#   'Or',
#   'is',
#   'it',
#   'where',
#   'we',
#   'would',
#   'have',
#   'thought',
#   'the',
#   'other',
#   'moon',
#   'would',
#   'have',
#   'been?',
#   'Like--'],
#  ['uh,',
#   'struggling',
#   'to',
#   'get',
#   'his',
#   'footing',
#   'like',
#   'the',
#   'two',
#   'of',
#   'you',
#   'are.',
#   'He’s-',
#   'he',
#   'doesn’t',
#   'seem',
#   'to',
#   'be',
#   'dizzy.',
#   'He',
#   'seems…',
#   'fine.',
#   'Magnus',
#   'Guys.',
#   'It’s',
#   'all',
#   'clear.',
#   'I',
#   'remember',
#   'everything.'],
#  ['that',
#   'was',
#   'at',
#   'the,',
#   'uh,',
#   'you',
#   'know,',
#   'that',
#   'caused',
#   'all',
#   'that',
#   'bad,',
#   'bad',
#   'shit',
#   'to',
#   'happen—',
#   'That',
#   'was',
#   'what',
#   'they',
#   'were',
#   'referring',
#   'to',
#   'as',
#   'the-',
#   'the',
#   'Phoenix',
#   'Fire',
#   'Gauntlet.',
#   'Mhm.'],
#  ['like—',
#   'I',
#   'might-',
#   'I',
#   'might',
#   'have',
#   'you',
#   'guys',
#   'do,',
#   'like',
#   'an',
#   'investigation',
#   'check',
#   'if',
#   'you',
#   'want',
#   'to',
#   'like,',
#   'try',
#   'and',
#   'deduce',
#   'what',
#   'the',
#   'hell',
#   'just',
#   'happened',
#   'to',
#   'you.',
#   '{5054}',
#   'Okay.'],
#  ['Uh,',
#   'yeah,',
#   'sure!',
#   'If',
#   'you',
#   'want.',
#   'Assuming',
#   'that',
#   'was',
#   'magical?',
#   'Yeah.',
#   'I-',
#   'I',
#   'mean,',
#   'actually',
#   'it',
#   'would',
#   'be',
#   'more',
#   'of',
#   'a,',
#   'uh—',
#   'is',
#   'there',
#   'like',
#   'a—',
#   'Well,',
#   'I',
#   'wouldn’t',
#   'know.'],
#  ['it',
#   'would',
#   'be',
#   'more',
#   'of',
#   'a,',
#   'uh—',
#   'is',
#   'there',
#   'like',
#   'a—',
#   'Well,',
#   'I',
#   'wouldn’t',
#   'know.',
#   'A',
#   'nature-',
#   'a',
#   'nature',
#   'check?',
#   'To',
#   'try',
#   'and',
#   'discern',
#   'what',
#   'kind',
#   'of',
#   'animal',
#   'this',
#   'is?'],
#  ['and',
#   'unguents,',
#   'and',
#   'formulas',
#   'and',
#   'stuff',
#   'like',
#   'that.',
#   'So',
#   'it',
#   'wasn’t',
#   'that,',
#   'and',
#   'it',
#   'wasn’t...',
#   'whatever',
#   'this',
#   'was,',
#   'you',
#   'get',
#   'the',
#   'impression',
#   'that',
#   'it',
#   'wasn’t...',
#   'magical.',
#   'No',
#   'magic',
#   'here.',
#   'Hmm.'],
#  ['it',
#   'wasn’t...',
#   'whatever',
#   'this',
#   'was,',
#   'you',
#   'get',
#   'the',
#   'impression',
#   'that',
#   'it',
#   'wasn’t...',
#   'magical.',
#   'No',
#   'magic',
#   'here.',
#   'Hmm.',
#   'Alright,',
#   'well',
#   'I',
#   'got',
#   'a',
#   'seventeen',
#   'investigation',
#   'check,',
#   'is',
#   'what',
#   'I',
#   'was',
#   'rolling.'],
#  ['a',
#   'roll',
#   'of',
#   'parchment,',
#   'and',
#   'you',
#   'hear',
#   'Johann',
#   'yell',
#   'out',
#   'Johann',
#   'Uh,',
#   'come',
#   'on',
#   'in,',
#   'let’s,',
#   'uh,',
#   'let’s',
#   'get',
#   'this',
#   'over',
#   'with.',
#   'I',
#   'hate—',
#   'This',
#   'is',
#   'my',
#   'least',
#   'favorite',
#   'part.'],
#  ['away.',
#   'Okay.',
#   'Yeah,',
#   'alright.',
#   'Uh.',
#   '[laughter]',
#   'So',
#   'what',
#   'you’re',
#   'gonna',
#   'have',
#   'to',
#   'do',
#   'is',
#   'make--',
#   'So',
#   'you’re',
#   'frisking',
#   'him',
#   'is',
#   'what',
#   'you’re',
#   'doing.',
#   'I’m',
#   'frisking',
#   'him.',
#   '“Don’t',
#   'mind',
#   'me,',
#   'sir.”'],
#  ['very',
#   'interesting',
#   'item!',
#   'This',
#   'is',
#   'called',
#   'the',
#   'True',
#   'Heart',
#   'Clasp.',
#   'Uh,',
#   'you',
#   'wear',
#   'it',
#   'on',
#   'your',
#   'ear,',
#   'and',
#   'it',
#   'uh,',
#   'aids',
#   'you',
#   'in',
#   'knowing',
#   'a',
#   'person’s',
#   'true',
#   'intentions.',
#   'Merle',
#   'Ooh!'],
#  ['very',
#   'interesting',
#   'item!',
#   'This',
#   'is',
#   'called',
#   'the',
#   'True',
#   'Heart',
#   'Clasp.',
#   'Uh,',
#   'you',
#   'wear',
#   'it',
#   'on',
#   'your',
#   'ear,',
#   'and',
#   'it',
#   'uh,',
#   'aids',
#   'you',
#   'in',
#   'knowing',
#   'a',
#   'person’s',
#   'true',
#   'intentions.',
#   'Merle',
#   'Ooh!'],
#  ['left.',
#   'Taako',
#   'To',
#   'the',
#   'right?',
#   'Merle',
#   '[whispering]',
#   'To',
#   'the',
#   'left!',
#   'Leon',
#   'Yes,',
#   'to',
#   'the',
#   'right.',
#   'Yes.',
#   'Now,',
#   'we’re',
#   'doing',
#   'the-',
#   'we’re',
#   'doing',
#   'the',
#   'goddamn',
#   'Cupid',
#   'Shuffle',
#   'now,',
#   'so',
#   'go',
#   'ahead--'],
#  ['what',
#   'I’m',
#   'looking',
#   'at',
#   'my--I',
#   'have',
#   'been',
#   'writing',
#   'it',
#   'all',
#   'down.',
#   'Um,',
#   'no…',
#   'Are',
#   'you',
#   'sure--',
#   'are',
#   'you',
#   'a',
#   'hundred',
#   'percent',
#   'sure?',
#   'No,',
#   'I',
#   'bluffed.',
#   '[',
#   'laughs]',
#   'Okay.',
#   '[',
#   'laughs]'],
#  ['train,',
#   'right?',
#   'Yes.',
#   'Um,',
#   'yeah.',
#   'Okay.',
#   'Taako',
#   'I',
#   'don’t',
#   'have',
#   'a--none',
#   'of',
#   'my',
#   'spells',
#   'sort',
#   'of',
#   'leap',
#   'to',
#   'mind',
#   'that',
#   'would',
#   'be,',
#   'uh,',
#   'helpful',
#   'to',
#   'us.',
#   'Um--',
#   'Your',
#   'uh--',
#   'Taako'],
#  ['Tasha’s',
#   'hideous',
#   'laughter,',
#   'nothing.',
#   'You',
#   'guys',
#   'have',
#   'any,',
#   'like,',
#   'spells,',
#   'or',
#   '[stuttering]',
#   'abilities?',
#   'Can',
#   'I',
#   'do',
#   'a',
#   'perception',
#   'check',
#   'to',
#   'see',
#   'if',
#   'I',
#   'can-',
#   'can',
#   'sense',
#   'any,',
#   'like,',
#   'train-like',
#   'activities?'],
#  ['the',
#   'canopy',
#   'of',
#   'the',
#   'trees',
#   'above.',
#   'And,',
#   'uh…',
#   'you',
#   'hear',
#   'a',
#   'goopy',
#   'sound.',
#   'Okay.',
#   'A',
#   'goopy',
#   'sound?',
#   'Yeah,',
#   'kind',
#   'of',
#   'like',
#   'a',
#   '[making',
#   'wet',
#   'noises',
#   'with',
#   'his',
#   'mouth]',
#   'Oh,',
#   'great.'],
#  ['like',
#   'a',
#   '[making',
#   'wet',
#   'noises',
#   'with',
#   'his',
#   'mouth]',
#   'Oh,',
#   'great.',
#   '[laughing]',
#   'Okay,',
#   'can',
#   'I',
#   'do',
#   'a,',
#   'uh',
#   '-',
#   'can',
#   'I',
#   'do',
#   'a',
#   'perception',
#   'check',
#   'to',
#   'see',
#   'if',
#   'any,',
#   'like',
#   '-'],
#  ['were',
#   'able',
#   'to',
#   'charm',
#   'the',
#   'last',
#   'Bodett',
#   'with',
#   'just',
#   'charm.',
#   'This',
#   'Bodett',
#   'is',
#   'too',
#   'wily',
#   'for',
#   'me,',
#   'I’m',
#   'gonna',
#   'have',
#   'to',
#   'use',
#   'magical',
#   'charm.',
#   'Okay.',
#   'Uh,',
#   'how',
#   'does',
#   'that',
#   'work?'],
#  ['the',
#   'other',
#   'side',
#   'of',
#   'the',
#   'car',
#   'is',
#   'a',
#   'young',
#   'boy,',
#   'who',
#   'is',
#   'wearing',
#   'a',
#   'fancy-boy',
#   'suit--',
#   'Mhm.',
#   '--and',
#   'a',
#   'fa-',
#   'a',
#   'blue',
#   'fancy',
#   'boy',
#   'cap.',
#   'Uh,',
#   'dressed',
#   'up',
#   'very',
#   'fanci-fancily.'],
#  ['Jenkins.',
#   'You',
#   'are',
#   'a',
#   'cad.',
#   'Jenkins',
#   '[crosstalk]',
#   'Nothing-',
#   'nothing-',
#   'nothing',
#   'could',
#   'destroy',
#   'memories.',
#   'Merle',
#   'And',
#   'let’s',
#   'leave',
#   'the',
#   'door',
#   'open,',
#   'shall',
#   'we?',
#   'Jenkins',
#   'Well,',
#   'yes,',
#   'it',
#   'would',
#   'have',
#   'to',
#   'be.'],
#  ['internet.',
#   '[crosstalk]',
#   'So',
#   'you’re',
#   'casting',
#   'na-na',
#   'na-na',
#   'boo',
#   'boo,',
#   'right?',
#   'Yeah,',
#   'I',
#   'roll…',
#   'Yeah,',
#   'I',
#   'rolled',
#   'a',
#   'fourteen,',
#   'and',
#   'I',
#   'have',
#   'a',
#   'plus',
#   'eighteen',
#   'to',
#   'bullying.',
#   'So',
#   'that’s',
#   'thirty-two.',
#   '[laughter]'],
#  ['book',
#   'to',
#   'Taako.',
#   'Angus',
#   'Okay,',
#   'so',
#   'we’re',
#   'doing',
#   'this',
#   'now,',
#   'huh?',
#   'Merle',
#   'It’s',
#   'called',
#   'monkey',
#   'in',
#   'the',
#   'middle.',
#   'Angus',
#   'I',
#   'know',
#   'what',
#   'it’s',
#   'called.',
#   'Magnus',
#   'No,',
#   'I—I',
#   'can’t',
#   'read',
#   'magic.'],
#  ['middle.',
#   'Angus',
#   'I',
#   'know',
#   'what',
#   'it’s',
#   'called.',
#   'Magnus',
#   'No,',
#   'I—I',
#   'can’t',
#   'read',
#   'magic.',
#   'Ok,',
#   'I',
#   'look',
#   'at',
#   'it',
#   'and',
#   'I',
#   'do',
#   'an',
#   'arcana',
#   'check',
#   'on',
#   'the',
#   'book.',
#   'You',
#   'already',
#   'did.'],
#  ['middle.',
#   'Angus',
#   'I',
#   'know',
#   'what',
#   'it’s',
#   'called.',
#   'Magnus',
#   'No,',
#   'I—I',
#   'can’t',
#   'read',
#   'magic.',
#   'Ok,',
#   'I',
#   'look',
#   'at',
#   'it',
#   'and',
#   'I',
#   'do',
#   'an',
#   'arcana',
#   'check',
#   'on',
#   'the',
#   'book.',
#   'You',
#   'already',
#   'did.'],
#  ['going--Angus',
#   'says,',
#   'uh,',
#   'Angus',
#   'Look',
#   'over',
#   'the',
#   'body',
#   'as',
#   'quick',
#   'as',
#   'you',
#   'can',
#   'before',
#   'anybody',
#   'else',
#   'gets',
#   'here.',
#   'That’s',
#   'my',
#   'job.',
#   'Let',
#   'me',
#   'look',
#   'at',
#   'the',
#   'body.',
#   'Wait--',
#   'Okay.',
#   'Hmm.'],
#  ['true.',
#   'I',
#   'wanna--',
#   'I',
#   'wanna',
#   'see',
#   'if-',
#   'if',
#   'the',
#   'rod',
#   'is',
#   'missing.',
#   'That’s',
#   'a',
#   'fair',
#   'question.',
#   'Uh,',
#   'okay,',
#   'you’re',
#   'gonna',
#   'do',
#   'that?',
#   'I',
#   'rolled',
#   'a',
#   '19.',
#   '[crosstalk]',
#   'What’re',
#   'we',
#   'rolling?'],
#  ['8',
#   'damage.',
#   'Okay.',
#   'And-',
#   'and',
#   'punched',
#   'him',
#   'out',
#   'a',
#   'window.',
#   'Okay.',
#   'Uhh.',
#   'Same',
#   'chance',
#   'to',
#   'resist',
#   '--',
#   'Wait',
#   'a',
#   'minute,',
#   'why',
#   'does',
#   'he',
#   'get',
#   'a',
#   'chance',
#   'to',
#   'resist',
#   'Phantom',
#   'Fist?'],
#  ['Jess',
#   'How',
#   'can',
#   'you',
#   'prove',
#   'that—how',
#   'can',
#   'you—no,',
#   'stop—how',
#   'can',
#   'you',
#   'prove',
#   'that',
#   'you',
#   'didn’t',
#   'cut',
#   'this',
#   'guy’s',
#   'head',
#   'off',
#   'with',
#   'your',
#   'grandmother’s',
#   'knife?',
#   'I',
#   'do—',
#   'Magnus',
#   'It’s',
#   'my',
#   'grandfather’s!'],
#  ['anything',
#   'like',
#   'that',
#   'that',
#   'seems',
#   'out',
#   'of',
#   'order.',
#   'Hey,',
#   'do',
#   'you',
#   'want',
#   'me',
#   'to',
#   'cast',
#   'Zone',
#   'of',
#   'Truth?',
#   '[laughing]',
#   'That',
#   'would',
#   'be—',
#   'Now',
#   'hold',
#   'on.',
#   '[bantering',
#   'about',
#   'Zone',
#   'of',
#   'Truth]'],
#  ['Now',
#   'hold',
#   'on.',
#   '[bantering',
#   'about',
#   'Zone',
#   'of',
#   'Truth]',
#   'Uh,',
#   'that',
#   'would',
#   'be,',
#   'that',
#   'would',
#   'be',
#   'an',
#   'investigation',
#   'check.',
#   'If',
#   'you,',
#   'if',
#   'you-',
#   'if',
#   'you’re',
#   'poring',
#   'over',
#   'like',
#   'a',
#   'specific',
#   'thing.'],
#  ['You--you--',
#   'you',
#   'are',
#   'not',
#   'hearing',
#   'anything',
#   'anymore.',
#   'As',
#   's-',
#   'as',
#   'you',
#   'move',
#   'into',
#   'the',
#   'room.',
#   'Uhhm.',
#   'And..',
#   '[crosstalk]',
#   '.',
#   'Angus',
#   'starts,',
#   'uh,',
#   'overturning',
#   'the',
#   'room,',
#   'looking',
#   'for',
#   'clues.',
#   'Yes,',
#   '?'],
#  ['And..',
#   '[crosstalk]',
#   '.',
#   'Angus',
#   'starts,',
#   'uh,',
#   'overturning',
#   'the',
#   'room,',
#   'looking',
#   'for',
#   'clues.',
#   'Yes,',
#   '?',
#   'Can',
#   'I',
#   'roll',
#   'a',
#   'perception',
#   'check',
#   'to',
#   'see',
#   'if',
#   'I',
#   'notice',
#   'anything',
#   'awry',
#   'about',
#   'the',
#   'safe?'],
#  ['uh,',
#   'uh,',
#   'dining',
#   'car',
#   'moves',
#   'into',
#   'the',
#   'train,',
#   'it,',
#   'uh,',
#   'begins',
#   'to',
#   'pull',
#   'the',
#   'rope',
#   'back',
#   'in',
#   'towards',
#   'the',
#   'train,',
#   'and',
#   'you',
#   'pop',
#   'this',
#   'heaviness',
#   'bean',
#   'in',
#   'your',
#   'mouth?',
#   'Mhm.'],
#  ['but',
#   'he’s',
#   'missing',
#   'two',
#   'teeth.',
#   'Great,',
#   'okay.',
#   'Is',
#   'everybody',
#   'else',
#   '-',
#   'uh,',
#   'can',
#   'everybody',
#   'else',
#   'hop',
#   'off?',
#   'I',
#   'jump,',
#   'but',
#   'I',
#   'tuck',
#   'and',
#   'roll',
#   'so',
#   'as',
#   'to',
#   'incur',
#   'no',
#   'damage.'],
#  ['real',
#   'easy',
#   'to',
#   'concentrate',
#   'when',
#   'you’re',
#   'rolling',
#   'across',
#   'those',
#   'railroad',
#   'ties.',
#   'No',
#   'I',
#   'mean',
#   'I’ll',
#   'hop',
#   'up',
#   'at',
#   'the',
#   'last',
#   'second,',
#   'it’s',
#   'gonna',
#   'be',
#   'sweet.',
#   'That',
#   'will',
#   'be',
#   'really',
#   'cool.'],
#  ['will',
#   'be',
#   'really',
#   'cool.',
#   'Well',
#   'let',
#   'me',
#   'get',
#   'an',
#   'acrobatic',
#   '-',
#   'what',
#   'is',
#   'it?',
#   'What',
#   'kind',
#   '-',
#   'do',
#   'I',
#   'need',
#   'to',
#   'do',
#   'an',
#   'acrobatics',
#   'check?',
#   'Or',
#   'am',
#   'I',
#   '-',
#   '[Crosstalk]'],
#  ['rub',
#   'it',
#   'in',
#   'his',
#   'face.',
#   'And',
#   'here’s',
#   'the',
#   'bad',
#   'thing,',
#   'only',
#   'one',
#   'of',
#   'us',
#   'actually',
#   'uses',
#   'a',
#   'CPAP',
#   'machine!',
#   'Why',
#   'am',
#   'I',
#   'laughing?',
#   'Taako',
#   'It’s',
#   'not',
#   'funny.',
#   'It’s',
#   'pretty',
#   'funny.'],
#  ['push',
#   'the',
#   'only',
#   'story',
#   'in',
#   'this',
#   'show',
#   'that',
#   'matters',
#   'forward.',
#   'Does',
#   '-',
#   'Does-',
#   'does',
#   'Magnus',
#   'look',
#   'like',
#   'he',
#   'has',
#   'like',
#   'bonuses',
#   'or',
#   'anything',
#   'now?',
#   'Does',
#   'he',
#   'look',
#   'like',
#   'bonus-y?',
#   'Uhh...'],
#  ['uh,',
#   'it’s',
#   'adventurezonecast@gmail.com',
#   'and',
#   'you',
#   'can',
#   'send',
#   'in',
#   'an',
#   'item.',
#   'Uh,',
#   'but',
#   'yeah.',
#   'Do',
#   'you',
#   'want',
#   'to',
#   'read',
#   'the',
#   'ones',
#   'that',
#   'people',
#   'sent',
#   'in?',
#   'You',
#   'don’t',
#   'have',
#   'to',
#   'read',
#   'yours.'],
#  ['[imitating',
#   'Snow]',
#   'A',
#   'licky',
#   'boom-boom,',
#   'downnnn.',
#   'Now',
#   'he',
#   'gets',
#   'it.',
#   'Why',
#   'did',
#   'you',
#   'licky',
#   'my',
#   'boom',
#   'boom',
#   'down?',
#   'I',
#   'don’t',
#   'understand.',
#   '[exhausted',
#   'inhale]',
#   'And,',
#   'I’m',
#   'dead.',
#   '[laughter]',
#   '{2310-2825}',
#   '[music',
#   'plays]'],
#  ['[imitating',
#   'Snow]',
#   'A',
#   'licky',
#   'boom-boom,',
#   'downnnn.',
#   'Now',
#   'he',
#   'gets',
#   'it.',
#   'Why',
#   'did',
#   'you',
#   'licky',
#   'my',
#   'boom',
#   'boom',
#   'down?',
#   'I',
#   'don’t',
#   'understand.',
#   '[exhausted',
#   'inhale]',
#   'And,',
#   'I’m',
#   'dead.',
#   '[laughter]',
#   '{2310-2825}',
#   '[music',
#   'plays]'],
#  ['[imitating',
#   'Snow]',
#   'A',
#   'licky',
#   'boom-boom,',
#   'downnnn.',
#   'Now',
#   'he',
#   'gets',
#   'it.',
#   'Why',
#   'did',
#   'you',
#   'licky',
#   'my',
#   'boom',
#   'boom',
#   'down?',
#   'I',
#   'don’t',
#   'understand.',
#   '[exhausted',
#   'inhale]',
#   'And,',
#   'I’m',
#   'dead.',
#   '[laughter]',
#   '{2310-2825}',
#   '[music',
#   'plays]'],
#  ['still',
#   'have',
#   'to',
#   'climb',
#   'it!',
#   'Athletics',
#   'is',
#   'Strength.',
#   'Um,',
#   'no,',
#   'we',
#   'already',
#   'knew',
#   'that.',
#   'So,',
#   'Athletics,',
#   'um…',
#   'is,',
#   '[reading',
#   'from',
#   'handbook]',
#   'difficult',
#   'situations',
#   'you',
#   'encounter',
#   'while',
#   'climbing,',
#   'jumping',
#   'or',
#   'swimming.'],
#  ['just',
#   'doing',
#   'a',
#   'sort',
#   'of',
#   '‘24’-esque',
#   'splitscreen.',
#   'Uh,',
#   'back',
#   'to',
#   'Merle,',
#   'and',
#   'uh,',
#   'back',
#   'to',
#   'Magnus',
#   'and',
#   'Taako-',
#   'um,',
#   'the',
#   'rope’s',
#   'in',
#   'your',
#   'car.',
#   'And',
#   'the',
#   'ball’s',
#   'in',
#   'your',
#   'court.'],
#  ['they’ve',
#   'hashtagged',
#   'it',
#   'out.',
#   'For',
#   'sure.',
#   'On',
#   'Twitterbook.',
#   'Yeah',
#   'all-',
#   'all',
#   'over',
#   'the',
#   'place.',
#   '[interrupting',
#   'loudly]',
#   'Are',
#   'you',
#   'gonna',
#   'try-',
#   'Okay.',
#   'Climb',
#   'my',
#   'body.',
#   'Merle',
#   'Alright,',
#   'I’ll',
#   'climb!',
#   'I’ll',
#   'climb.'],
#  ['[laugh]',
#   'Magnus',
#   'Merle…',
#   'Merle.',
#   'Good',
#   'lord.',
#   'Merle',
#   'Hey,',
#   'it',
#   'was',
#   'your',
#   'suggestion!',
#   '[deep',
#   'inhale]',
#   'Uh,',
#   'the',
#   'vines',
#   'are',
#   'now',
#   'about',
#   '15',
#   'feet',
#   'below',
#   'you.',
#   'Merle',
#   'Alright,',
#   'what',
#   'do',
#   'I',
#   'roll?'],
#  ['I',
#   'wrote',
#   'my',
#   'name',
#   'on',
#   'it!',
#   'I-',
#   'I-',
#   'I',
#   'mean',
#   'I',
#   'oughta',
#   'be',
#   'able',
#   'to',
#   'get',
#   'it',
#   'back.',
#   'If',
#   'lost,',
#   'please',
#   'return',
#   'this',
#   'crowbar.',
#   'To-',
#   '[laughs]',
#   'Some',
#   'guy.',
#   'Okay.',
#   'Uhhh-'],
#  ['[laughs]',
#   'Some',
#   'guy.',
#   'Okay.',
#   'Uhhh-',
#   'I’m',
#   'gonna',
#   'roll',
#   'a',
#   'perception',
#   'check.',
#   'Okay.',
#   'Nice.',
#   'I',
#   'rolled…',
#   'A',
#   '13,',
#   'plus',
#   '0.',
#   'Mkay.',
#   'Everything',
#   'is',
#   'shitty.',
#   'This',
#   'whole',
#   'situation',
#   'sucks',
#   'for',
#   'you.',
#   '[laughing]'],
#  ['there.',
#   'So',
#   'we',
#   'need',
#   'to',
#   'move',
#   'to',
#   'the',
#   'next',
#   'level,',
#   'and',
#   'see',
#   'if',
#   'there’s-',
#   'if',
#   'it’s',
#   'empty.',
#   'Alright.',
#   'I’m-',
#   'I’m',
#   'gonna',
#   'move',
#   'this',
#   'forward.',
#   'Dad.',
#   'Climb.',
#   'Okay.',
#   'We',
#   'gotta',
#   'climb.'],
#  ['you’re',
#   'gonna',
#   'bamf',
#   'up',
#   'to',
#   'it,',
#   'you’re',
#   'not-',
#   'I’ve',
#   'reappeared',
#   '10',
#   'feet',
#   'up',
#   'the',
#   'rope.',
#   'Mkay.',
#   'So-',
#   'I',
#   'wanna',
#   'go',
#   'to',
#   'floor',
#   '14.',
#   'Okay-',
#   'That’s',
#   'where',
#   'I’m',
#   'goin’.',
#   'Floor',
#   '14.'],
#  ['damn',
#   'pants',
#   'up’',
#   'check?',
#   'Nope.',
#   'Yeah.',
#   'Can',
#   '-',
#   'Can',
#   'I',
#   'check',
#   'to',
#   'see',
#   'if-',
#   'Oh!',
#   'I',
#   'rolled',
#   'a',
#   '0.',
#   '[laughs]',
#   'I',
#   'don’t',
#   'know',
#   'what',
#   'to',
#   'tell',
#   'you.',
#   'Whoa,',
#   'that’s',
#   'weird.'],
#  ['to',
#   'notice',
#   'that',
#   'I’m',
#   'wearing',
#   'MeUndies.',
#   'They',
#   'are',
#   'incredibly',
#   'comfortable.',
#   'Oh-!',
#   'No,',
#   'excuse',
#   'me,',
#   'I',
#   'am',
#   'wearing',
#   '‘YeUndies’.',
#   'YeUndies!',
#   '[laughs]',
#   'This',
#   'portion',
#   'of',
#   'our',
#   'podcast',
#   'brought',
#   'to',
#   'you',
#   'by',
#   'YeUndies.'],
#  ['again.',
#   'Oh!',
#   'Okay.',
#   'Uh,',
#   'I',
#   'rear',
#   'back',
#   'my',
#   'axe,',
#   'and',
#   'then',
#   'I',
#   'grab',
#   'the',
#   'belt.',
#   'Mkay.',
#   'So',
#   'that’s',
#   'a',
#   '17,',
#   '[mumbles]',
#   'ummm…',
#   'So',
#   'is',
#   'that',
#   'sleight',
#   'of',
#   'hand?',
#   'Or',
#   'deception.'],
#  ['I’ve',
#   'investigated',
#   'her.',
#   'But',
#   'uh-',
#   'I’ve',
#   'tried',
#   'to',
#   'bust',
#   'her,',
#   'y’know',
#   'I',
#   'just,',
#   'I',
#   'when',
#   'I',
#   'see',
#   'a',
#   'perp,',
#   'I',
#   'just',
#   'uh',
#   'I',
#   'think,',
#   '‘I’ve',
#   'go-',
#   'I',
#   'gotta',
#   'bust',
#   'her!’'],
#  ['can',
#   'buy',
#   'a',
#   'Goldcliff',
#   'magnet.',
#   'Yay!',
#   'I’m',
#   'adding',
#   'that',
#   'to',
#   'my',
#   'inventory.',
#   'Okay,',
#   'but',
#   'it-',
#   'it',
#   'cost',
#   'you',
#   '600-',
#   'it',
#   'cost',
#   'you',
#   '600',
#   'gold',
#   'pieces.',
#   '[',
#   'laughing]',
#   'I',
#   'steal',
#   'it.'],
#  ['it-',
#   'it',
#   'cost',
#   'you',
#   '600-',
#   'it',
#   'cost',
#   'you',
#   '600',
#   'gold',
#   'pieces.',
#   '[',
#   'laughing]',
#   'I',
#   'steal',
#   'it.',
#   'M’kay,',
#   'roll',
#   'a',
#   'sleight',
#   'of',
#   'hand',
#   'check.',
#   'Aww.',
#   'That’s',
#   '-',
#   'I',
#   'rolled',
#   'a',
#   '12.'],
#  ['And',
#   'uh,',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'the',
#   'room,',
#   'uh,',
#   'is,',
#   'uh,',
#   'a',
#   'large',
#   'wagon',
#   'shaped',
#   'object',
#   'that',
#   'is',
#   'covered',
#   'by',
#   'a',
#   'huge',
#   'brown',
#   'tarp',
#   'that',
#   'has',
#   'been',
#   'thrown',
#   'over',
#   'it—'],
#  ['over',
#   'it—',
#   'I’m',
#   'gonna',
#   'roll',
#   'a',
#   'perception',
#   'check.',
#   'See',
#   'if',
#   'I',
#   'notice',
#   'anything',
#   'about',
#   'the',
#   'object',
#   'in',
#   'the',
#   'tarp',
#   'or',
#   'in',
#   'the',
#   'room.',
#   'Natural',
#   '20',
#   'plus',
#   'one,',
#   '21.',
#   'Ok!',
#   'Um,'],
#  ['promise',
#   'you',
#   'this.',
#   'Are',
#   'we',
#   'out',
#   'of',
#   'the',
#   'zone',
#   'of',
#   'truth?',
#   'Yeah,',
#   'yeah.',
#   'You’re',
#   'far',
#   'away',
#   'from',
#   'it.',
#   'Taako',
#   'Everything’s',
#   'gonna',
#   'be',
#   'fine.',
#   '[',
#   ',',
#   'and',
#   'laughing]',
#   '{Break',
#   'from',
#   '3805-4407}'],
#  ['No,',
#   'where',
#   'like,',
#   'they',
#   'think,',
#   'like,',
#   '“we’ve',
#   'got',
#   'this!',
#   'We’re',
#   'gonna',
#   'win',
#   'the',
#   'big',
#   'race!”',
#   'But',
#   'really',
#   'she’s',
#   'not',
#   'very',
#   'good.',
#   'I',
#   'mean',
#   'she',
#   'seems',
#   'really',
#   'confident',
#   'in',
#   'herself.',
#   'Okay.'],
#  ['says.',
#   '[Everyone',
#   'laughing]',
#   'Come',
#   'watch',
#   'me',
#   'poop.',
#   'Merle,',
#   'clobber',
#   'him.',
#   'I',
#   'gotta',
#   'roll',
#   'to',
#   'see',
#   'if',
#   'I',
#   'have',
#   'to',
#   'poop',
#   'cuz',
#   'I',
#   'need',
#   'to',
#   'make',
#   'this',
#   'look',
#   'real.',
#   'Constipation',
#   'check.'],
#  ['thank',
#   'you',
#   'for',
#   'reminding',
#   'me,',
#   '.',
#   'Okay.',
#   'Aw,',
#   'shit.',
#   'Yeah,',
#   'exactly.',
#   'Which',
#   'part?',
#   'The',
#   'part',
#   'that',
#   'I’m',
#   'Jerry',
#   'or',
#   'the',
#   'part',
#   'that',
#   'I',
#   'have',
#   'to',
#   'use',
#   'the',
#   'bathroom',
#   'very',
#   'bad?'],
#  ['beat]',
#   'Sorry,',
#   'I',
#   'had',
#   'a',
#   'seizure.',
#   'Let’s-',
#   'listen.',
#   'We',
#   'gotta',
#   'kill',
#   'this',
#   'imposter.',
#   'Or',
#   'throw',
#   '‘im',
#   'in',
#   'a',
#   'well,',
#   'or',
#   'somethin’.',
#   'Uh-',
#   'he-',
#   'Taako',
#   '[as',
#   'Little',
#   'Jerry]',
#   'Let’s',
#   'well',
#   '‘im.'],
#  ['ya',
#   'what,',
#   'bud.',
#   'Why',
#   'don’t',
#   'you',
#   'actually',
#   'tell',
#   'me…',
#   'my',
#   'real',
#   'name?',
#   '[nervous',
#   'laughter]',
#   'Okay,',
#   'I-',
#   'roll',
#   'a--',
#   'Okay,',
#   'let’s',
#   'Sherlock',
#   'this',
#   'out.',
#   'There',
#   'was',
#   'a',
#   'smudge',
#   'on',
#   'his',
#   'collar.'],
#  ['a',
#   'nuclear',
#   'bomb―',
#   'A',
#   'magic',
#   'card.',
#   'Right,',
#   'the',
#   'Phantom',
#   'Fist',
#   'allows',
#   'you',
#   'to',
#   'punch',
#   'enemies',
#   'and',
#   'move',
#   'them',
#   'far',
#   'away',
#   'from',
#   'you',
#   'but',
#   'it-',
#   'it',
#   'will',
#   'not',
#   'melt',
#   'steel',
#   'beams.'],
#  ['a',
#   'nuclear',
#   'bomb―',
#   'A',
#   'magic',
#   'card.',
#   'Right,',
#   'the',
#   'Phantom',
#   'Fist',
#   'allows',
#   'you',
#   'to',
#   'punch',
#   'enemies',
#   'and',
#   'move',
#   'them',
#   'far',
#   'away',
#   'from',
#   'you',
#   'but',
#   'it-',
#   'it',
#   'will',
#   'not',
#   'melt',
#   'steel',
#   'beams.'],
#  ['but',
#   'it-',
#   'it',
#   'will',
#   'not',
#   'melt',
#   'steel',
#   'beams.',
#   'I',
#   'would',
#   'like',
#   'to',
#   'roll',
#   'a',
#   'perception',
#   'check,',
#   'maybe?',
#   'Insight',
#   'check?',
#   'To',
#   'see',
#   'if',
#   'Magnus',
#   'thinks',
#   'he',
#   'could',
#   'chop',
#   'the',
#   'lock,',
#   'given―'],
#  ['the,',
#   'the',
#   'hot',
#   'Goldcliff',
#   'sun.',
#   'Eugh.',
#   'I',
#   'fully',
#   'rock',
#   'out.',
#   'What',
#   'do',
#   'you--',
#   'what',
#   'do',
#   'you',
#   'mean',
#   'by',
#   'that?',
#   'Like',
#   'The',
#   'Rock,',
#   'he’s',
#   'a-',
#   'What?',
#   'He’s',
#   'a',
#   'big,',
#   'burly',
#   'man.'],
#  ['as',
#   'a',
#   'free',
#   'action,',
#   'use',
#   'my',
#   'Lens',
#   'of',
#   'Straight',
#   'Creepin’',
#   'to',
#   'see',
#   'where',
#   'the',
#   'door',
#   'went.',
#   'Uh,',
#   'that’s',
#   'not',
#   'how',
#   'it',
#   'works.',
#   'It',
#   'leaves',
#   'tracks',
#   'in',
#   'the',
#   'ground.',
#   'Augh!',
#   'Dammit.'],
#  ['Lens',
#   'of',
#   'Straight',
#   'Creepin’',
#   'to',
#   'see',
#   'where',
#   'the',
#   'door',
#   'went.',
#   'Uh,',
#   'that’s',
#   'not',
#   'how',
#   'it',
#   'works.',
#   'It',
#   'leaves',
#   'tracks',
#   'in',
#   'the',
#   'ground.',
#   'Augh!',
#   'Dammit.',
#   'I',
#   'mean,',
#   'you',
#   'could',
#   'perception',
#   'check.'],
# ...
#   'just',
#   'going',
#   'to',
#   'roll',
#   'this',
#   'Strength.',
#   '[',
#   'rolls',
#   'dice',
#   'and',
#   'then',
#   'laughs',
#   'heartily]',
#   'Is',
#   'it',
#   'Alabaster’s?',
#   '[still',
#   'laughing]',
#   'Oh',
#   'my',
#   'god!',
#   'It’s',
#   'Alabaster’s',
#   'isn’t',
#   'it?'],
#  ['like',
#   'this',
#   'is',
#   'mood',
#   'lighting',
#   'of',
#   'his',
#   'aura.',
#   'Alright.',
#   'While',
#   "I'm",
#   'this',
#   'close,',
#   'do',
#   'I',
#   'notice',
#   'anything?',
#   'Is',
#   'he',
#   'wearing',
#   'any',
#   'kind',
#   'of',
#   'battery,',
#   'or',
#   'tool,',
#   'or',
#   'necklace,',
#   'or',
#   'anything?'],
#  ['40',
#   'feet,',
#   'so',
#   'I',
#   'think',
#   'he',
#   'probably',
#   'is',
#   'up',
#   'with',
#   'them,',
#   'right?',
#   'Yeah.',
#   'You',
#   'are',
#   'like',
#   'crowding',
#   'the',
#   'grappler',
#   'and',
#   'the',
#   'barrel',
#   'at',
#   'this',
#   'point.',
#   'You',
#   "can't",
#   'do',
#   'much,',
#   'yeah.'],
#  ['[disappointed]',
#   'It’s',
#   'a',
#   '10…',
#   'No,',
#   'no!',
#   'My',
#   'mojo!',
#   'It',
#   'took',
#   'your',
#   'mojo',
#   'away!',
#   'What',
#   'if',
#   'I',
#   'did',
#   'like',
#   'a',
#   'front',
#   'flip',
#   'and',
#   'then',
#   'shot',
#   'him.',
#   'Then',
#   'could',
#   'I',
#   'use',
#   'acrobatics?'],
#  ['and',
#   'columns',
#   'and…',
#   'Yeah,',
#   'yeah.',
#   'Like',
#   'cutting',
#   'through',
#   'air.',
#   'Like',
#   'a',
#   'ship.',
#   '[laughing]',
#   'I',
#   'don’t',
#   'know',
#   'why',
#   'that',
#   'got',
#   'me.',
#   'That’s',
#   'very',
#   'good.',
#   'Like',
#   'a',
#   'clipper',
#   'sailing',
#   'through',
#   'the',
#   'wind!'],
#  ['pull',
#   'things',
#   'off',
#   'of',
#   'the',
#   'wall',
#   'in',
#   'the',
#   'dressing',
#   'room.',
#   'And',
#   'you',
#   'just',
#   'have',
#   'a',
#   'smelter,',
#   'like',
#   'in',
#   'the',
#   'corner,',
#   'that',
#   'you',
#   'pull',
#   'out',
#   'of',
#   'the',
#   'closet.',
#   'I',
#   'mean',
#   'obviously.'],
#  ['(as',
#   'Inara)',
#   "We're",
#   'not',
#   'just',
#   'going',
#   'to',
#   'hand',
#   'over',
#   'an',
#   'ancient',
#   'relic',
#   'from',
#   'The',
#   'Centering',
#   'to',
#   'just',
#   'anyone.',
#   'We',
#   'wanted',
#   'to',
#   'make',
#   'sure',
#   'you',
#   'knew',
#   'what',
#   'you',
#   'were',
#   'going',
#   'for.'],
#  ['and',
#   'everyone',
#   'will',
#   'just',
#   'pretend',
#   'that',
#   'they',
#   'knew',
#   'about',
#   'it',
#   'and',
#   'then',
#   'think',
#   'that',
#   'they',
#   'forgot?',
#   '(as',
#   'Kohl)',
#   'I',
#   'think',
#   'I',
#   'have',
#   'an',
#   'idea.',
#   '[short',
#   'pause]',
#   '[metallic',
#   'foreboding',
#   'music',
#   'begins]'],
#  ['played',
#   'Dungeons',
#   'and/or',
#   'Dragons.',
#   '[',
#   'gasps',
#   'excitedly]',
#   'How',
#   'did',
#   'it',
#   'stack',
#   'up?',
#   'Mike',
#   'It',
#   'felt',
#   'great,',
#   'my',
#   'first',
#   '3',
#   'rolls',
#   'were',
#   'fucking',
#   'dope!',
#   '[',
#   'laughing]',
#   'You',
#   'rolled',
#   'very',
#   'well!',
#   'Mike'],
#  ['really',
#   'but',
#   'I',
#   'can',
#   'make',
#   'myself',
#   'look',
#   'different',
#   'and',
#   'my',
#   'clothes',
#   'look',
#   'different.',
#   'Oh,',
#   'Cool.',
#   'The',
#   'cape',
#   'spin',
#   'was',
#   'just',
#   'flare.',
#   '[',
#   '&',
#   'laughing]',
#   ',',
#   'what',
#   'does',
#   'the',
#   'text',
#   'say?'],
#  ['hear,',
#   'there',
#   'are',
#   'crowds',
#   'that',
#   'are',
#   'lined',
#   'up',
#   'outside',
#   'of',
#   'the',
#   'arena,',
#   'like',
#   'kind',
#   'of',
#   'tailgating',
#   'before',
#   'the',
#   'game.',
#   '[gasping]',
#   'What',
#   'are',
#   'they',
#   'making?!',
#   'Yeah,',
#   'what',
#   'are',
#   'these',
#   'dope',
#   'snacks?'],
#  ['-',
#   'I',
#   '[contemplating]',
#   '…',
#   'but',
#   'the',
#   'dog',
#   'did',
#   'a',
#   'big,',
#   'POOF!',
#   'Mike',
#   '(as',
#   'Twister)',
#   'No!',
#   'Reginald',
#   'this',
#   'dog’s',
#   'name',
#   'is',
#   'Oatcake.',
#   'That',
#   'doesn’t',
#   'even',
#   'sound',
#   'like',
#   'Lucius,',
#   'you’re',
#   'being',
#   'ridiculous.'],
#  ['(as',
#   'Twister)',
#   '[hesitantly]',
#   'Wait,',
#   'you',
#   'guys-you',
#   'want',
#   'to',
#   'go',
#   'backstage?',
#   '(as',
#   'Tracey)',
#   'We',
#   'have',
#   'a',
#   'package',
#   'we',
#   'have',
#   'to',
#   'deliver.',
#   '(as',
#   'Inara)',
#   'Yeah.',
#   'Mike',
#   '(as',
#   'Twister)',
#   'Oh,',
#   'well.',
#   'Alright,',
#   'uh…'],
#  ['Oh',
#   'yeah,',
#   'no,',
#   'I',
#   'wonder',
#   'if',
#   'they',
#   'got',
#   'my',
#   'writer',
#   'in',
#   'time,',
#   'because…',
#   'And',
#   'then',
#   'I’ll',
#   'just',
#   'try',
#   'to',
#   'mutter,',
#   'like,',
#   '[',
#   'incoherently',
#   'mumbles]',
#   'And',
#   'point',
#   'to',
#   'the',
#   'paper.',
#   'Right.'],
#  ['the',
#   'hallway',
#   'slightly,',
#   'and',
#   'then',
#   'start',
#   'to',
#   'ride',
#   'down.',
#   'I’m',
#   'going',
#   'to',
#   'circle',
#   'the',
#   'ring',
#   'once',
#   'and',
#   'then',
#   'twice,',
#   'and',
#   'kickflip',
#   'over',
#   'the',
#   'rope',
#   'into',
#   'the',
#   'center',
#   'of',
#   'the',
#   'ring.'],
#  ['Sweet!',
#   'Wow,',
#   'we’ll',
#   'be',
#   'invested',
#   'in',
#   'the',
#   'same',
#   'outcome.',
#   'Yeah,',
#   'I’ll',
#   'go',
#   'through',
#   'and',
#   'I',
#   'can',
#   'use',
#   'some',
#   'of',
#   'that',
#   'plumber',
#   'lingo',
#   'that',
#   'I’m',
#   'used',
#   'to',
#   'using',
#   'on',
#   'the',
#   'day-to-day.'],
#  ['to',
#   'you,',
#   'or',
#   'you',
#   'can',
#   'do',
#   'a',
#   'History',
#   'check',
#   'to',
#   'see',
#   'if',
#   'you',
#   'remember',
#   'which',
#   'one,',
#   'which',
#   'one',
#   'are',
#   'the',
#   'deluxe',
#   'suites.',
#   'So,',
#   'it',
#   'would',
#   'have',
#   'the',
#   'headliners',
#   'in.',
#   'Mike'],
#  ['aspect',
#   'of',
#   'it,',
#   'and',
#   'then',
#   'put',
#   'a',
#   'tiny',
#   'piece',
#   'of',
#   'catnip',
#   'on',
#   'the',
#   'end',
#   'and',
#   'the',
#   'cat',
#   'would',
#   'crawl',
#   'out.',
#   'You',
#   're-adjust',
#   'and',
#   're-tighten',
#   'the',
#   'nut.',
#   '[',
#   'cackles]',
#   'Nailed',
#   'it!'],
#  ['Gordon',
#   'Lighthammer.',
#   'Who',
#   'blessedly',
#   'doesn’t',
#   'stick',
#   'his',
#   'head',
#   'out',
#   'the',
#   'door',
#   'frame',
#   'to',
#   'see',
#   'where',
#   'you’re',
#   'going.',
#   '(as',
#   'Gordon',
#   'Lighthammer)',
#   'I’m',
#   'only',
#   'going',
#   'to',
#   'look',
#   'this',
#   'way!',
#   'See',
#   'you',
#   'later!'],
#  ['Smart.',
#   'Good.',
#   'Yeah,',
#   'I’m',
#   'going',
#   'to',
#   'try',
#   'and',
#   'pick',
#   'the',
#   'drawers',
#   'one',
#   'by',
#   'one.',
#   'First,',
#   'sort',
#   'of',
#   'assessing',
#   'them,',
#   'to',
#   'see',
#   'if',
#   'I',
#   'can',
#   'sense',
#   'any',
#   'trap',
#   'or',
#   'anti-theft',
#   'situation.'],
#  ['was',
#   'posturing',
#   'because',
#   'he',
#   'was',
#   'trying',
#   'to',
#   'figure',
#   'out',
#   'what',
#   'the',
#   'best',
#   'method',
#   'of',
#   'getting',
#   'out',
#   'of',
#   'these',
#   'chains',
#   'would',
#   'be.',
#   'It',
#   'clearly',
#   'was',
#   'not',
#   'posturing',
#   'being',
#   'murderous.',
#   '[',
#   'chuckles]'],
#  ['Tracey)',
#   '[whispering',
#   'back]',
#   'Okay.',
#   'Beep',
#   'boop.',
#   'And',
#   'then,',
#   'um,',
#   'I’m',
#   'going',
#   'to',
#   'duck',
#   'into',
#   'a',
#   'supply',
#   'closet',
#   'that',
#   'is',
#   'conveniently',
#   'on',
#   'the',
#   'hallway.',
#   'I',
#   'go',
#   'into',
#   'the',
#   'supply',
#   'closet',
#   'too.'],
#  ['obvious',
#   'that',
#   'it’s',
#   'you!!',
#   '[',
#   '&',
#   'laughing]',
#   '[still',
#   'laughing]',
#   'When',
#   'you',
#   'say',
#   'that,',
#   'he',
#   'pulls',
#   'like,',
#   'a',
#   'cloak',
#   'out',
#   'of',
#   'his',
#   'pocket',
#   '[',
#   'laughing',
#   'heartily]',
#   'and',
#   'throws',
#   'it',
#   'over',
#   'Tracey.'],
#  ['obvious',
#   'that',
#   'it’s',
#   'you!!',
#   '[',
#   '&',
#   'laughing]',
#   '[still',
#   'laughing]',
#   'When',
#   'you',
#   'say',
#   'that,',
#   'he',
#   'pulls',
#   'like,',
#   'a',
#   'cloak',
#   'out',
#   'of',
#   'his',
#   'pocket',
#   '[',
#   'laughing',
#   'heartily]',
#   'and',
#   'throws',
#   'it',
#   'over',
#   'Tracey.'],
#  ['can',
#   'see',
#   'that',
#   'there',
#   'is',
#   'a',
#   'mild',
#   'glow',
#   'that',
#   'you’ve',
#   'also',
#   'like',
#   'recognized',
#   'before.',
#   'This',
#   'isn’t',
#   'like',
#   'malicious',
#   'overhead',
#   'lighting,',
#   'this',
#   'is',
#   'like',
#   'a',
#   'nice',
#   'warm',
#   'glow',
#   'from',
#   'down',
#   'there.'],
#  ['like',
#   'recognized',
#   'before.',
#   'This',
#   'isn’t',
#   'like',
#   'malicious',
#   'overhead',
#   'lighting,',
#   'this',
#   'is',
#   'like',
#   'a',
#   'nice',
#   'warm',
#   'glow',
#   'from',
#   'down',
#   'there.',
#   'And',
#   'can',
#   'I',
#   'place',
#   'that',
#   'at',
#   'all?',
#   'Can',
#   'I',
#   'roll',
#   'History?'],
#  ['an',
#   'entire',
#   'pie.',
#   'Lingonberry',
#   'rhubarb,',
#   'something',
#   'that',
#   'she',
#   'had',
#   'saved',
#   'just',
#   'for',
#   'this',
#   'occasion.',
#   'Uh',
#   'yeah,',
#   'Head,',
#   'slash,',
#   'ship',
#   'by',
#   'ship,',
#   'OTP,',
#   'OTP3,',
#   'OC11,',
#   'slash',
#   'slash',
#   'slash...',
#   '[Electronic',
#   'music',
#   'transitions]'],
#  ['an',
#   'entire',
#   'pie.',
#   'Lingonberry',
#   'rhubarb,',
#   'something',
#   'that',
#   'she',
#   'had',
#   'saved',
#   'just',
#   'for',
#   'this',
#   'occasion.',
#   'Uh',
#   'yeah,',
#   'Head,',
#   'slash,',
#   'ship',
#   'by',
#   'ship,',
#   'OTP,',
#   'OTP3,',
#   'OC11,',
#   'slash',
#   'slash',
#   'slash...',
#   '[Electronic',
#   'music',
#   'transitions]'],
#  ['I',
#   'do',
#   'think',
#   'we’re',
#   'friends.',
#   'Tracey',
#   'slowly',
#   'nods',
#   'once.',
#   '(as',
#   'Driftwood',
#   'Franny',
#   'Sunflower)',
#   'Do',
#   'you',
#   'know',
#   'what',
#   'the',
#   'thing',
#   'is',
#   'that',
#   'powers',
#   'your',
#   'whole',
#   'biz?',
#   'Tracey',
#   'shakes',
#   'his',
#   'head',
#   'no.'],
#  ['sound.',
#   '[everyone',
#   'laughing',
#   'mixed',
#   'with',
#   'Tracey’s',
#   'muffled',
#   'screams]',
#   'So,',
#   'I',
#   'get',
#   'advantage',
#   'if',
#   'a',
#   'creature',
#   'I’m',
#   'trying',
#   'to',
#   'attach',
#   'hasn’t',
#   'taken',
#   'a',
#   'turn,',
#   'and',
#   'I',
#   'auto-crit',
#   'on',
#   'surprised',
#   'creatures,',
#   'so...'],
#  ['you’ve',
#   'seen',
#   'it',
#   'before,',
#   'but',
#   'if',
#   'you',
#   'see',
#   'it',
#   'I',
#   'would',
#   'love',
#   'to',
#   'get',
#   'my',
#   'hand',
#   'on',
#   'it',
#   'cause',
#   'I',
#   'think',
#   'it’s',
#   'tied',
#   'to',
#   'all',
#   'these',
#   'things',
#   'happening',
#   'right',
#   'now.'],
#  ['going',
#   'to',
#   'go',
#   'to',
#   'the',
#   'kitchen',
#   'and',
#   'start',
#   'trying',
#   'to',
#   'pull',
#   'out',
#   'some',
#   'tea',
#   'or',
#   'coffee,',
#   'whatever',
#   'I',
#   'found',
#   'there.',
#   'And',
#   'make',
#   'it',
#   'for',
#   'the',
#   'group',
#   'as',
#   'we',
#   'get',
#   'up.'],
#  ['guess',
#   'not.',
#   'But',
#   'we',
#   'still',
#   'don’t-',
#   'I',
#   'really',
#   'thought',
#   'we',
#   'were',
#   'going',
#   'to',
#   'catch',
#   'him.',
#   'We',
#   'still',
#   'don’t',
#   'really',
#   'know',
#   'what',
#   'is',
#   'happening',
#   'with',
#   'Alonzo,',
#   'you',
#   'know',
#   'what',
#   'I',
#   'mean?'],
#  ['[announcing',
#   'loudly]',
#   'Come',
#   'one,',
#   'come',
#   'all!',
#   'I',
#   'have',
#   'a',
#   'question',
#   'and',
#   'a',
#   'request.',
#   'Okay.',
#   'One,',
#   'does',
#   'Tallahassee',
#   'know',
#   'how',
#   'to',
#   'play',
#   'chess?',
#   'We’re',
#   'about',
#   'to',
#   'find',
#   'out-',
#   'Guess',
#   'we’ll',
#   'see!'],
#  ['guess',
#   'I’ll',
#   'lurk',
#   'around',
#   'also.',
#   'And',
#   'maybe',
#   'in',
#   'addition,',
#   'if',
#   'there',
#   'are',
#   'people',
#   'waiting',
#   'on',
#   'line',
#   'I',
#   'will',
#   'talk',
#   'to',
#   'them',
#   'as',
#   'well-',
#   'Cool,',
#   'cool,',
#   'cool.',
#   'About',
#   'the',
#   'Midnight',
#   'Man.'],
#  ['guess',
#   'I’ll',
#   'lurk',
#   'around',
#   'also.',
#   'And',
#   'maybe',
#   'in',
#   'addition,',
#   'if',
#   'there',
#   'are',
#   'people',
#   'waiting',
#   'on',
#   'line',
#   'I',
#   'will',
#   'talk',
#   'to',
#   'them',
#   'as',
#   'well-',
#   'Cool,',
#   'cool,',
#   'cool.',
#   'About',
#   'the',
#   'Midnight',
#   'Man.'],
#  ['guess',
#   'I’ll',
#   'lurk',
#   'around',
#   'also.',
#   'And',
#   'maybe',
#   'in',
#   'addition,',
#   'if',
#   'there',
#   'are',
#   'people',
#   'waiting',
#   'on',
#   'line',
#   'I',
#   'will',
#   'talk',
#   'to',
#   'them',
#   'as',
#   'well-',
#   'Cool,',
#   'cool,',
#   'cool.',
#   'About',
#   'the',
#   'Midnight',
#   'Man.'],
#  ['as',
#   'Autumn)',
#   'Alright,',
#   'thanks',
#   'again.',
#   '(as',
#   'Miss',
#   'Morgan)',
#   'That',
#   'is',
#   'so',
#   'kind.',
#   'Autumn…',
#   'last',
#   'name?',
#   'Autumn…?',
#   '(as',
#   'Inara,',
#   'as',
#   'Autumn)',
#   '[unsure]',
#   'Breeze…',
#   '[laughing',
#   'in',
#   'the',
#   'background]',
#   '(as',
#   'Miss',
#   'Morgan)',
#   'Breeze…'],
#  ['work',
#   '[chuckling]',
#   'And',
#   'then',
#   'hands',
#   'the',
#   'glittering',
#   'chunk',
#   'of',
#   'rock',
#   'to',
#   'Finale.',
#   '[',
#   'giggling]',
#   'Character',
#   'growth.',
#   'And',
#   'then',
#   'mimes,',
#   'like',
#   'Head,',
#   'rock,',
#   'hit.',
#   '(as',
#   'Finale)',
#   '[whispering]',
#   'I',
#   'got',
#   'you',
#   'Tracey'],
#  ['[Door',
#   'slams]',
#   'And',
#   'as',
#   'you',
#   'descend,',
#   'floors',
#   'and',
#   'floors',
#   'down,',
#   'you',
#   'hear',
#   'the',
#   'light',
#   'and',
#   'effervescent',
#   'sound-',
#   '[Mellow',
#   'elevator',
#   'music',
#   'begins]',
#   'Of',
#   'elevator',
#   'music.',
#   '[Mellow',
#   'elevator',
#   'music',
#   'slowly',
#   'fades',
#   'out]'],
#  ['forcefield',
#   'is.',
#   'Okay,',
#   'the',
#   'force',
#   'field',
#   'is',
#   'similar',
#   'magic',
#   'to',
#   'what',
#   'you',
#   'feel',
#   'was',
#   'powering',
#   'Alabaster.',
#   'If',
#   'I',
#   'walk',
#   'around',
#   'it,',
#   'is',
#   'there',
#   'any',
#   'obvious',
#   'break',
#   'in',
#   'the',
#   'field?',
#   'Or…?'],
#  ['I',
#   'walk',
#   'around',
#   'it,',
#   'is',
#   'there',
#   'any',
#   'obvious',
#   'break',
#   'in',
#   'the',
#   'field?',
#   'Or…?',
#   'Make',
#   'an',
#   'investigation',
#   'check.',
#   'Does',
#   'anyone',
#   'else',
#   'want',
#   'to',
#   'make',
#   'a',
#   'check',
#   'while',
#   'Brando',
#   'is',
#   'doing',
#   'this?'],
#  ['this',
#   'episode?',
#   'Or',
#   'what',
#   'kind',
#   'of,',
#   'I',
#   'don’t',
#   'know,',
#   'long-term',
#   'reveals',
#   'you',
#   'might',
#   'want',
#   'to',
#   'reveal?',
#   '[',
#   'chuckles]',
#   'Or',
#   'did',
#   'you',
#   'then',
#   'choose',
#   'the',
#   'setting',
#   'for',
#   'it?',
#   'Or',
#   'vice',
#   'versa?'],
#  ['a',
#   'drink.',
#   'Do',
#   'you',
#   'think',
#   'maybe',
#   'we',
#   'should',
#   'talk',
#   'down',
#   'there?',
#   'Wink.',
#   '[',
#   'laughs]',
#   '(as',
#   'Tracey)',
#   'Inara,',
#   'she',
#   'just',
#   'said',
#   'wink',
#   'out',
#   'loud,',
#   'can',
#   'you',
#   'just',
#   'do',
#   'that?!',
#   '(as',
#   'Inara)'],
#  ['know',
#   'where',
#   'you',
#   'are',
#   'going.',
#   'This',
#   'kenku,',
#   'is',
#   'like,',
#   'the',
#   'door',
#   'person.',
#   '(as',
#   'Finale)',
#   'Yeah,',
#   'maybe',
#   'we',
#   'should',
#   'leave',
#   'the',
#   'teethling',
#   'here?',
#   'I’m',
#   'sure',
#   'they',
#   'can',
#   'take',
#   'care',
#   'of',
#   'it.'],
#  ['Can',
#   'I',
#   'roll',
#   'an',
#   'investigation',
#   'check',
#   'to',
#   'see',
#   'how',
#   'trustworthy',
#   'this',
#   'door',
#   'attendant',
#   'is?',
#   'And',
#   'the',
#   'general',
#   'vibe,',
#   'if',
#   'we',
#   'can',
#   'leave',
#   'Kohl',
#   'here',
#   'to',
#   'recuperate',
#   'or',
#   'sleep',
#   'it',
#   'off?'],
#  ['off?',
#   'So,',
#   'you',
#   'can',
#   'do',
#   'an',
#   'investigation',
#   'check',
#   'to',
#   'check',
#   'out',
#   'the',
#   'room',
#   'or',
#   'you',
#   'can',
#   'do',
#   'an',
#   'inside',
#   'check',
#   'to',
#   'check',
#   'the',
#   'kenku.',
#   'Let’s',
#   'do',
#   'inside.',
#   'Okay',
#   '[dice',
#   'rolls]'],
#  ['[chuckles],',
#   '4+5',
#   'for',
#   'a',
#   '9.',
#   'It’s',
#   'so',
#   'weird,',
#   'how',
#   'they’re',
#   'making',
#   'different',
#   'sounds',
#   'with',
#   'their',
#   'mouth.',
#   '[',
#   'laughs]',
#   'Rude.',
#   '[',
#   'continues',
#   'laughing]',
#   'Rude.',
#   'I',
#   'have',
#   'talked',
#   'with',
#   'kenku',
#   'before,',
#   'sir.'],
#  ['booth.',
#   '(as',
#   'Inara)',
#   'Booths',
#   'are',
#   'great.',
#   '(as',
#   'Mac)',
#   'But',
#   'also,',
#   'also',
#   'you’ve',
#   'got',
#   'to',
#   'pay',
#   'for',
#   'these.',
#   '(as',
#   'Inara)',
#   'Start',
#   'a',
#   'tab.',
#   '(as',
#   'Mac)',
#   'That’s',
#   'fair.',
#   'Alright',
#   'Finale’s',
#   'tab.',
#   'Good.'],
#  ['booth.',
#   '(as',
#   'Inara)',
#   'Booths',
#   'are',
#   'great.',
#   '(as',
#   'Mac)',
#   'But',
#   'also,',
#   'also',
#   'you’ve',
#   'got',
#   'to',
#   'pay',
#   'for',
#   'these.',
#   '(as',
#   'Inara)',
#   'Start',
#   'a',
#   'tab.',
#   '(as',
#   'Mac)',
#   'That’s',
#   'fair.',
#   'Alright',
#   'Finale’s',
#   'tab.',
#   'Good.'],
#  ['the',
#   'booth,',
#   'I',
#   'want',
#   'to',
#   'make',
#   'a',
#   'investigation',
#   'check',
#   'or',
#   'a',
#   'perception',
#   'check,',
#   'just',
#   'to',
#   'see',
#   'if',
#   'there',
#   'is',
#   'anyone',
#   'in',
#   'the',
#   'bar',
#   'that',
#   'we',
#   'need',
#   'to',
#   'be',
#   'worried',
#   'about.'],
#  ...]

# %%
# Transforma uma lista de 2 dimensões em 1
flat_list = [item for sublist in full_list for item in sublist]
flat_list
# Out:
# ['going',
#  'weekly',
#  'for',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'experimental',
#  'arcs',
#  '[',
#  'Woohoo!]',
#  'starting',
#  'this',
#  'week.',
#  'So,',
#  'um,',
#  'I',
#  'guess',
#  'actually',
#  'we',
#  'have',
#  'an',
#  'episode—',
#  'I',
#  'hope',
#  'we',
#  'don’t',
#  'screw',
#  'it',
#  'up!',
#  'by,',
#  'like,',
#  'logic,',
#  'you',
#  'know',
#  'what',
#  'I',
#  'mean?',
#  'So',
#  'I',
#  'can’t',
#  'be',
#  'like,',
#  '“I',
#  'wanna',
#  'Help',
#  'Out',
#  'by…”',
#  '[inhaling',
#  'sharply',
#  'through',
#  'teeth]',
#  'Ssssssssssssss...',
#  'Ooooh,',
#  'logic.',
#  '“...pulling',
#  'the',
#  'sun',
#  'down.”',
#  'Yeah.',
#  'success,',
#  'you',
#  'open',
#  'yourself',
#  'up',
#  'to',
#  'repercussions.',
#  'To,',
#  'like,',
#  'the',
#  'same',
#  'reper—',
#  'so',
#  'you',
#  'can',
#  'help',
#  'out,',
#  'yeah,',
#  'but',
#  'you',
#  'are',
#  'also',
#  'exposing',
#  'yourself',
#  'to',
#  'danger,',
#  'which',
#  'is',
#  'real',
#  'smart.',
#  'success,',
#  'you',
#  'open',
#  'yourself',
#  'up',
#  'to',
#  'repercussions.',
#  'To,',
#  'like,',
#  'the',
#  'same',
#  'reper—',
#  'so',
#  'you',
#  'can',
#  'help',
#  'out,',
#  'yeah,',
#  'but',
#  'you',
#  'are',
#  'also',
#  'exposing',
#  'yourself',
#  'to',
#  'danger,',
#  'which',
#  'is',
#  'real',
#  'smart.',
#  'play',
#  'in',
#  'the',
#  'NFL!”',
#  'and',
#  'he',
#  'was',
#  'like',
#  '“No.”',
#  'There’s',
#  'some',
#  'really-',
#  'we',
#  'haven’t—',
#  'I',
#  'really',
#  'like',
#  'this',
#  'idea',
#  'of',
#  'a',
#  'Chosen',
#  'that’s',
#  'just',
#  'like',
#  '[crosstalk]',
#  '“No,',
#  'no',
#  'thank',
#  'you!”',
#  'you',
#  'are',
#  'dealing',
#  'with',
#  'the',
#  'consequences',
#  'of',
#  'your',
#  'own',
#  'spellcasting.',
#  'That’s',
#  'definitely',
#  'this.',
#  'Um.',
#  'Yeah',
#  'so-',
#  'but',
#  'if',
#  'it’s',
#  'Weird,',
#  'I',
#  'rolled',
#  'an',
#  'eight',
#  'plus',
#  'two',
#  'so',
#  'it’s',
#  'a',
#  '10.',
#  'booze',
#  'in',
#  'a',
#  'Arnold',
#  'Palmer.',
#  'I',
#  'mean,',
#  'sometimes',
#  'there',
#  'is.',
#  'Arnold',
#  'Palmer',
#  'loves',
#  'to',
#  'party.',
#  '[',
#  'and',
#  'laugh]',
#  "That's",
#  'true,',
#  'yeah.',
#  '[chuckles]',
#  'Sometimes',
#  'there',
#  'is',
#  'booze',
#  'in',
#  'an',
#  'Arnold.',
#  '[Laughter]',
#  'no.',
#  'Yeah,',
#  'so',
#  'go',
#  'ahead',
#  'and',
#  'mark',
#  'experience.',
#  'Yes,',
#  'but',
#  "don't",
#  'you',
#  'see?',
#  'I',
#  "don't",
#  'want',
#  'to',
#  'have',
#  'failed.',
#  '[crosstalk]',
#  'Did',
#  'you',
#  'think',
#  'about',
#  'it',
#  'that',
#  'way?',
#  '[crosstalk]',
#  'Mmm,',
#  'interesting.',
#  'he’s',
#  'kind',
#  'of',
#  'leaning',
#  'backwards,',
#  'shooting',
#  'at',
#  'the',
#  'snake',
#  'along',
#  'the',
#  'length',
#  'of',
#  'its',
#  'watery',
#  'body,',
#  'and',
#  'basically',
#  'heading',
#  'towards',
#  'one',
#  'of',
#  'the',
#  'big',
#  'water',
#  'slides,',
#  'just',
#  'away',
#  'from',
#  'them.',
#  'I',
#  'just',
#  'think',
#  'it’s',
#  'information',
#  'we',
#  'need.',
#  '’s',
#  'gonna',
#  'Investigate',
#  'a',
#  'Mystery.',
#  'Ok.',
#  'And…',
#  'Roll',
#  'plus',
#  'Sharp.',
#  '[',
#  'rolls]',
#  'That’s',
#  'very',
#  'bad.',
#  '[quietly]',
#  'Shit.',
#  'You',
#  'did',
#  'a',
#  'bad',
#  'job,',
#  'Dad.',
#  'trying',
#  'to',
#  'wait',
#  'this',
#  'thing',
#  'out--',
#  'Yeah,',
#  'I',
#  'think',
#  'hiding',
#  'is',
#  'a',
#  'wonderful',
#  'choice;',
#  'this',
#  'is',
#  'the',
#  'choice',
#  'to',
#  'make.',
#  'Is',
#  'there',
#  'a',
#  'Hide',
#  'Under',
#  'Pressure?',
#  '[laughing]',
#  'Hide',
#  'Under',
#  'Bed?',
#  'Yeah,',
#  'I',
#  'love',
#  'it.',
#  'Mark',
#  'Luck,',
#  'and',
#  'you',
#  'have',
#  'spent',
#  'one',
#  'Luck.',
#  'Hey,',
#  'and',
#  'I',
#  'wanna',
#  'do',
#  'a',
#  'cool',
#  'line.',
#  'Yeah,',
#  'yeah,',
#  'do',
#  'a',
#  'cool',
#  'line.',
#  'Aubrey',
#  'Fuego,',
#  'ya',
#  'bastard!',
#  'Just',
#  'another',
#  'one',
#  'of',
#  'the',
#  'many',
#  'services',
#  'we',
#  'offer',
#  'from',
#  'the',
#  'Forestry',
#  'Service.',
#  'Swimmer',
#  'Is',
#  'clothes—',
#  'Oh!',
#  'Okay,',
#  'I’m',
#  'going,',
#  'I’m',
#  'going,',
#  'I’m',
#  'going!',
#  'Duck',
#  'Go!',
#  'Go!',
#  'Go!',
#  'Go!',
#  'Go!',
#  'rites',
#  'of',
#  'Omec,',
#  'and',
#  'you',
#  'and',
#  'your',
#  'companions,',
#  'that’s',
#  'you',
#  'guys,',
#  'can',
#  'expect',
#  'to',
#  'receive',
#  'free',
#  'healing',
#  'and',
#  'care',
#  'at',
#  'a',
#  'temple,',
#  'shrine,',
#  'or',
#  'other',
#  'established',
#  'presence',
#  'of',
#  'Omec’s',
#  'faith.',
#  'impotent',
#  'rage.',
#  'No,',
#  'he',
#  'wants,',
#  'uh',
#  '-',
#  'And',
#  'a',
#  'two',
#  'minute',
#  'song.',
#  'He',
#  'was',
#  'thinking',
#  'more',
#  'along',
#  'the',
#  'lines',
#  'of',
#  'slaying,',
#  'protecting,',
#  'guidance',
#  '-',
#  'Ah.',
#  'Got',
#  'it.',
#  'Adventuring,',
#  'essentially.',
#  'Excellent.',
#  'offered',
#  'you',
#  'a',
#  '-',
#  '10',
#  'gold',
#  'pieces',
#  'apiece.',
#  'and',
#  'Each?',
#  'Each,',
#  'yes.',
#  'Nice.',
#  'Which,',
#  'um,',
#  'I',
#  'mean,',
#  "I'm",
#  'not',
#  'your',
#  'boss,',
#  'but',
#  "that's",
#  'not',
#  'a',
#  'lot',
#  'of',
#  'money.',
#  'But',
#  'hey-',
#  'on',
#  'the',
#  'coast.',
#  "You've",
#  'taken',
#  'the',
#  'off-ramp,',
#  'uh,',
#  'that',
#  'will',
#  'lead',
#  'you',
#  'to',
#  'Phandalin,',
#  'and',
#  'things',
#  'definitely',
#  'are',
#  'not',
#  'as',
#  'well',
#  'maintained.',
#  'Lot',
#  'of',
#  'potholes.',
#  "Don't",
#  'worry,',
#  'I',
#  'got',
#  'this.',
#  'Merle?',
#  '[dice',
#  'rolling]',
#  'Pshew.',
#  'Wow.',
#  'Uh...',
#  '6.',
#  'And',
#  "what'd",
#  'you',
#  'get,',
#  '?',
#  'I',
#  'got',
#  'a',
#  'crit',
#  '20,',
#  'so',
#  'that’s',
#  '23?',
#  '23.',
#  'Okay.',
#  'You',
#  'see',
#  'the',
#  'shit',
#  'out',
#  'of',
#  'everything.',
#  'Mhm.',
#  'to',
#  'a',
#  'stop,',
#  'about',
#  'two-hundred',
#  'feet',
#  'out-',
#  'And',
#  'I',
#  'motion',
#  'silently,',
#  'to',
#  'get',
#  'the',
#  'attention',
#  'of',
#  'Merle',
#  'and',
#  'Taako,',
#  'and',
#  'kinda',
#  'pull',
#  'them',
#  'up',
#  'towards',
#  'the',
#  'front',
#  'of',
#  'the',
#  'wagon.',
#  'is',
#  'where,',
#  "who's",
#  'fighting',
#  'whom...',
#  'so',
#  'yeah,',
#  'you',
#  'can',
#  'take',
#  'a',
#  'movement,',
#  'up',
#  'to',
#  'your',
#  'speed,',
#  'you',
#  'can-',
#  'Do',
#  'I',
#  'have',
#  'to',
#  'take',
#  'a',
#  'movement?',
#  'You',
#  'do',
#  'not,',
#  'no.',
#  'Okay.',
#  'using',
#  'an',
#  'object,',
#  'like,',
#  'maneuvering',
#  'a',
#  'complicated,',
#  'like,',
#  'device?',
#  'That',
#  'will',
#  'take',
#  'an',
#  'action.',
#  'It’s',
#  'kinda',
#  'up',
#  'to',
#  'my',
#  'discretion',
#  'what',
#  'does',
#  'and',
#  'doesn’t',
#  'take',
#  'up',
#  'an',
#  'action.',
#  'Okay,',
#  'I-',
#  'forty',
#  'feet',
#  'out.',
#  'Okay,',
#  'now,',
#  'question.',
#  'Yeah.',
#  'Do',
#  'I',
#  'see',
#  'the',
#  'one',
#  'in',
#  'the',
#  'brush?',
#  '…',
#  'Um…',
#  'You',
#  'actually',
#  'do',
#  'not?',
#  'is',
#  'the',
#  'one',
#  'who',
#  'spotted',
#  'him.',
#  'Oh',
#  'okay.',
#  'Um-',
#  'probably',
#  'about',
#  'fifteen',
#  'to',
#  'twenty',
#  'feet',
#  'away',
#  'from',
#  'you,',
#  'he’s',
#  'not',
#  'right',
#  'next',
#  'to',
#  'the',
#  'wagon',
#  'so',
#  'that’s',
#  'a,',
#  'that’s',
#  'a-',
#  'Well,',
#  'Magnus',
#  'has',
#  'a',
#  'vertical',
#  'leap',
#  'of',
#  'eighteen',
#  'feet.',
#  'just',
#  'barely,',
#  'you',
#  'throw',
#  'it',
#  'into',
#  'the',
#  'woods,',
#  'you',
#  'can’t',
#  'exactly',
#  'see-',
#  'you',
#  'see',
#  'like',
#  'a,',
#  'branches',
#  'rustling,',
#  'and',
#  'you',
#  'throw',
#  'your',
#  'axe',
#  'in',
#  'that',
#  'direction',
#  'and',
#  'you',
#  'hear,',
#  'Gerblin',
#  'just',
#  'barely,',
#  'you',
#  'throw',
#  'it',
#  'into',
#  'the',
#  'woods,',
#  'you',
#  'can’t',
#  'exactly',
#  'see-',
#  'you',
#  'see',
#  'like',
#  'a,',
#  'branches',
#  'rustling,',
#  'and',
#  'you',
#  'throw',
#  'your',
#  'axe',
#  'in',
#  'that',
#  'direction',
#  'and',
#  'you',
#  'hear,',
#  'Gerblin',
#  'just',
#  'barely,',
#  'you',
#  'throw',
#  'it',
#  'into',
#  'the',
#  'woods,',
#  'you',
#  'can’t',
#  'exactly',
#  'see-',
#  'you',
#  'see',
#  'like',
#  'a,',
#  'branches',
#  'rustling,',
#  'and',
#  'you',
#  'throw',
#  'your',
#  'axe',
#  'in',
#  'that',
#  'direction',
#  'and',
#  'you',
#  'hear,',
#  'Gerblin',
#  'just',
#  'barely,',
#  'you',
#  'throw',
#  'it',
#  'into',
#  'the',
#  'woods,',
#  'you',
#  'can’t',
#  'exactly',
#  'see-',
#  'you',
#  'see',
#  'like',
#  'a,',
#  'branches',
#  'rustling,',
#  'and',
#  'you',
#  'throw',
#  'your',
#  'axe',
#  'in',
#  'that',
#  'direction',
#  'and',
#  'you',
#  'hear,',
#  'Gerblin',
#  'we’re',
#  'here.',
#  'A',
#  'wave',
#  'of',
#  'bats-',
#  'Taako',
#  'Excellent.',
#  '-comes',
#  'pouring',
#  'out.',
#  'A',
#  'wave',
#  'of',
#  'gas?',
#  'Bats.',
#  'Bats.',
#  'Bats.',
#  'Bats.',
#  'Baseball',
#  'bats.',
#  'Do',
#  'the',
#  'bats',
#  'have',
#  'gas?',
#  'They',
#  'definitely',
#  'do,',
#  'yeah.',
#  'draw',
#  'closer',
#  'to',
#  'them,',
#  'they',
#  'seem',
#  'more',
#  'agitated.',
#  'Couple',
#  'of',
#  'them',
#  'are',
#  'snarling',
#  'at',
#  'you',
#  'now.',
#  'Uh,',
#  'they',
#  'are-',
#  'But',
#  'there’s',
#  'nothing',
#  'else',
#  'in',
#  'the',
#  'room',
#  'other',
#  'than',
#  'these',
#  'wolves?',
#  '‘so',
#  'there’s',
#  'some',
#  'wolves',
#  'down',
#  'there,',
#  'it',
#  'doesn’t',
#  'seem',
#  'like',
#  'it’s',
#  'worth',
#  'it,',
#  'let’s',
#  'keep',
#  'going.’',
#  'Taako',
#  'Excellent,',
#  'well,',
#  'I',
#  'trust',
#  'your',
#  'judgement.',
#  'Okay,',
#  'I’m',
#  'into',
#  'that.',
#  'Off',
#  'we',
#  'go.',
#  'can-',
#  'Alright,',
#  'I',
#  'will',
#  'climb',
#  '-',
#  'I,',
#  'I',
#  'will',
#  'climb.',
#  'What',
#  'do',
#  'I',
#  'need',
#  'to',
#  'do?',
#  'Uh,',
#  'you',
#  'will',
#  'make',
#  'a-',
#  'I’m',
#  'gonna',
#  'try',
#  'to',
#  'climb',
#  'up,',
#  'to',
#  'the',
#  'overpass.',
#  'the',
#  'bridge',
#  'is',
#  'relatively',
#  'rickety,',
#  'it’s',
#  'of',
#  'gerblin,',
#  'uh,',
#  'construction,',
#  'so',
#  'it’s',
#  'not',
#  'amazing,',
#  'but',
#  'it',
#  'looks',
#  'like',
#  'it’ll',
#  'hold',
#  'your',
#  'weight.',
#  'Okay.',
#  'So',
#  'I',
#  'roll',
#  'a',
#  '20',
#  'sided',
#  'die?',
#  'it',
#  'looks',
#  'like',
#  'it’ll',
#  'hold',
#  'your',
#  'weight.',
#  'Okay.',
#  'So',
#  'I',
#  'roll',
#  'a',
#  '20',
#  'sided',
#  'die?',
#  'You',
#  'roll',
#  'a',
#  '20',
#  'sided',
#  'die,',
#  'and',
#  'you',
#  'add',
#  'your,',
#  'uh,',
#  'your',
#  'Athletics.',
#  '[dice',
#  'roll]',
#  'does',
#  'that',
#  'sound',
#  'funny?',
#  '[talking',
#  'at',
#  'the',
#  'same',
#  'time',
#  'as',
#  ...]

# %%
# Transforma tudo que não sejam números ou letras em string vazia, passa para letra minúscula
filtered_flat_list = [re.sub('[^A-Za-z0-9]+', '', i).lower() for i in flat_list]
# Remove as strings vazias da lista
filtered_flat_list = [x for x in filtered_flat_list if x]
filtered_flat_list
# Out:
# ['going',
#  'weekly',
#  'for',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'experimental',
#  'arcs',
#  'woohoo',
#  'starting',
#  'this',
#  'week',
#  'so',
#  'um',
#  'i',
#  'guess',
#  'actually',
#  'we',
#  'have',
#  'an',
#  'episode',
#  'i',
#  'hope',
#  'we',
#  'dont',
#  'screw',
#  'it',
#  'up',
#  'by',
#  'like',
#  'logic',
#  'you',
#  'know',
#  'what',
#  'i',
#  'mean',
#  'so',
#  'i',
#  'cant',
#  'be',
#  'like',
#  'i',
#  'wanna',
#  'help',
#  'out',
#  'by',
#  'inhaling',
#  'sharply',
#  'through',
#  'teeth',
#  'ssssssssssssss',
#  'ooooh',
#  'logic',
#  'pulling',
#  'the',
#  'sun',
#  'down',
#  'yeah',
#  'success',
#  'you',
#  'open',
#  'yourself',
#  'up',
#  'to',
#  'repercussions',
#  'to',
#  'like',
#  'the',
#  'same',
#  'reper',
#  'so',
#  'you',
#  'can',
#  'help',
#  'out',
#  'yeah',
#  'but',
#  'you',
#  'are',
#  'also',
#  'exposing',
#  'yourself',
#  'to',
#  'danger',
#  'which',
#  'is',
#  'real',
#  'smart',
#  'success',
#  'you',
#  'open',
#  'yourself',
#  'up',
#  'to',
#  'repercussions',
#  'to',
#  'like',
#  'the',
#  'same',
#  'reper',
#  'so',
#  'you',
#  'can',
#  'help',
#  'out',
#  'yeah',
#  'but',
#  'you',
#  'are',
#  'also',
#  'exposing',
#  'yourself',
#  'to',
#  'danger',
#  'which',
#  'is',
#  'real',
#  'smart',
#  'play',
#  'in',
#  'the',
#  'nfl',
#  'and',
#  'he',
#  'was',
#  'like',
#  'no',
#  'theres',
#  'some',
#  'really',
#  'we',
#  'havent',
#  'i',
#  'really',
#  'like',
#  'this',
#  'idea',
#  'of',
#  'a',
#  'chosen',
#  'thats',
#  'just',
#  'like',
#  'crosstalk',
#  'no',
#  'no',
#  'thank',
#  'you',
#  'you',
#  'are',
#  'dealing',
#  'with',
#  'the',
#  'consequences',
#  'of',
#  'your',
#  'own',
#  'spellcasting',
#  'thats',
#  'definitely',
#  'this',
#  'um',
#  'yeah',
#  'so',
#  'but',
#  'if',
#  'its',
#  'weird',
#  'i',
#  'rolled',
#  'an',
#  'eight',
#  'plus',
#  'two',
#  'so',
#  'its',
#  'a',
#  '10',
#  'booze',
#  'in',
#  'a',
#  'arnold',
#  'palmer',
#  'i',
#  'mean',
#  'sometimes',
#  'there',
#  'is',
#  'arnold',
#  'palmer',
#  'loves',
#  'to',
#  'party',
#  'and',
#  'laugh',
#  'thats',
#  'true',
#  'yeah',
#  'chuckles',
#  'sometimes',
#  'there',
#  'is',
#  'booze',
#  'in',
#  'an',
#  'arnold',
#  'laughter',
#  'no',
#  'yeah',
#  'so',
#  'go',
#  'ahead',
#  'and',
#  'mark',
#  'experience',
#  'yes',
#  'but',
#  'dont',
#  'you',
#  'see',
#  'i',
#  'dont',
#  'want',
#  'to',
#  'have',
#  'failed',
#  'crosstalk',
#  'did',
#  'you',
#  'think',
#  'about',
#  'it',
#  'that',
#  'way',
#  'crosstalk',
#  'mmm',
#  'interesting',
#  'hes',
#  'kind',
#  'of',
#  'leaning',
#  'backwards',
#  'shooting',
#  'at',
#  'the',
#  'snake',
#  'along',
#  'the',
#  'length',
#  'of',
#  'its',
#  'watery',
#  'body',
#  'and',
#  'basically',
#  'heading',
#  'towards',
#  'one',
#  'of',
#  'the',
#  'big',
#  'water',
#  'slides',
#  'just',
#  'away',
#  'from',
#  'them',
#  'i',
#  'just',
#  'think',
#  'its',
#  'information',
#  'we',
#  'need',
#  's',
#  'gonna',
#  'investigate',
#  'a',
#  'mystery',
#  'ok',
#  'and',
#  'roll',
#  'plus',
#  'sharp',
#  'rolls',
#  'thats',
#  'very',
#  'bad',
#  'quietly',
#  'shit',
#  'you',
#  'did',
#  'a',
#  'bad',
#  'job',
#  'dad',
#  'trying',
#  'to',
#  'wait',
#  'this',
#  'thing',
#  'out',
#  'yeah',
#  'i',
#  'think',
#  'hiding',
#  'is',
#  'a',
#  'wonderful',
#  'choice',
#  'this',
#  'is',
#  'the',
#  'choice',
#  'to',
#  'make',
#  'is',
#  'there',
#  'a',
#  'hide',
#  'under',
#  'pressure',
#  'laughing',
#  'hide',
#  'under',
#  'bed',
#  'yeah',
#  'i',
#  'love',
#  'it',
#  'mark',
#  'luck',
#  'and',
#  'you',
#  'have',
#  'spent',
#  'one',
#  'luck',
#  'hey',
#  'and',
#  'i',
#  'wanna',
#  'do',
#  'a',
#  'cool',
#  'line',
#  'yeah',
#  'yeah',
#  'do',
#  'a',
#  'cool',
#  'line',
#  'aubrey',
#  'fuego',
#  'ya',
#  'bastard',
#  'just',
#  'another',
#  'one',
#  'of',
#  'the',
#  'many',
#  'services',
#  'we',
#  'offer',
#  'from',
#  'the',
#  'forestry',
#  'service',
#  'swimmer',
#  'is',
#  'clothes',
#  'oh',
#  'okay',
#  'im',
#  'going',
#  'im',
#  'going',
#  'im',
#  'going',
#  'duck',
#  'go',
#  'go',
#  'go',
#  'go',
#  'go',
#  'rites',
#  'of',
#  'omec',
#  'and',
#  'you',
#  'and',
#  'your',
#  'companions',
#  'thats',
#  'you',
#  'guys',
#  'can',
#  'expect',
#  'to',
#  'receive',
#  'free',
#  'healing',
#  'and',
#  'care',
#  'at',
#  'a',
#  'temple',
#  'shrine',
#  'or',
#  'other',
#  'established',
#  'presence',
#  'of',
#  'omecs',
#  'faith',
#  'impotent',
#  'rage',
#  'no',
#  'he',
#  'wants',
#  'uh',
#  'and',
#  'a',
#  'two',
#  'minute',
#  'song',
#  'he',
#  'was',
#  'thinking',
#  'more',
#  'along',
#  'the',
#  'lines',
#  'of',
#  'slaying',
#  'protecting',
#  'guidance',
#  'ah',
#  'got',
#  'it',
#  'adventuring',
#  'essentially',
#  'excellent',
#  'offered',
#  'you',
#  'a',
#  '10',
#  'gold',
#  'pieces',
#  'apiece',
#  'and',
#  'each',
#  'each',
#  'yes',
#  'nice',
#  'which',
#  'um',
#  'i',
#  'mean',
#  'im',
#  'not',
#  'your',
#  'boss',
#  'but',
#  'thats',
#  'not',
#  'a',
#  'lot',
#  'of',
#  'money',
#  'but',
#  'hey',
#  'on',
#  'the',
#  'coast',
#  'youve',
#  'taken',
#  'the',
#  'offramp',
#  'uh',
#  'that',
#  'will',
#  'lead',
#  'you',
#  'to',
#  'phandalin',
#  'and',
#  'things',
#  'definitely',
#  'are',
#  'not',
#  'as',
#  'well',
#  'maintained',
#  'lot',
#  'of',
#  'potholes',
#  'dont',
#  'worry',
#  'i',
#  'got',
#  'this',
#  'merle',
#  'dice',
#  'rolling',
#  'pshew',
#  'wow',
#  'uh',
#  '6',
#  'and',
#  'whatd',
#  'you',
#  'get',
#  'i',
#  'got',
#  'a',
#  'crit',
#  '20',
#  'so',
#  'thats',
#  '23',
#  '23',
#  'okay',
#  'you',
#  'see',
#  'the',
#  'shit',
#  'out',
#  'of',
#  'everything',
#  'mhm',
#  'to',
#  'a',
#  'stop',
#  'about',
#  'twohundred',
#  'feet',
#  'out',
#  'and',
#  'i',
#  'motion',
#  'silently',
#  'to',
#  'get',
#  'the',
#  'attention',
#  'of',
#  'merle',
#  'and',
#  'taako',
#  'and',
#  'kinda',
#  'pull',
#  'them',
#  'up',
#  'towards',
#  'the',
#  'front',
#  'of',
#  'the',
#  'wagon',
#  'is',
#  'where',
#  'whos',
#  'fighting',
#  'whom',
#  'so',
#  'yeah',
#  'you',
#  'can',
#  'take',
#  'a',
#  'movement',
#  'up',
#  'to',
#  'your',
#  'speed',
#  'you',
#  'can',
#  'do',
#  'i',
#  'have',
#  'to',
#  'take',
#  'a',
#  'movement',
#  'you',
#  'do',
#  'not',
#  'no',
#  'okay',
#  'using',
#  'an',
#  'object',
#  'like',
#  'maneuvering',
#  'a',
#  'complicated',
#  'like',
#  'device',
#  'that',
#  'will',
#  'take',
#  'an',
#  'action',
#  'its',
#  'kinda',
#  'up',
#  'to',
#  'my',
#  'discretion',
#  'what',
#  'does',
#  'and',
#  'doesnt',
#  'take',
#  'up',
#  'an',
#  'action',
#  'okay',
#  'i',
#  'forty',
#  'feet',
#  'out',
#  'okay',
#  'now',
#  'question',
#  'yeah',
#  'do',
#  'i',
#  'see',
#  'the',
#  'one',
#  'in',
#  'the',
#  'brush',
#  'um',
#  'you',
#  'actually',
#  'do',
#  'not',
#  'is',
#  'the',
#  'one',
#  'who',
#  'spotted',
#  'him',
#  'oh',
#  'okay',
#  'um',
#  'probably',
#  'about',
#  'fifteen',
#  'to',
#  'twenty',
#  'feet',
#  'away',
#  'from',
#  'you',
#  'hes',
#  'not',
#  'right',
#  'next',
#  'to',
#  'the',
#  'wagon',
#  'so',
#  'thats',
#  'a',
#  'thats',
#  'a',
#  'well',
#  'magnus',
#  'has',
#  'a',
#  'vertical',
#  'leap',
#  'of',
#  'eighteen',
#  'feet',
#  'just',
#  'barely',
#  'you',
#  'throw',
#  'it',
#  'into',
#  'the',
#  'woods',
#  'you',
#  'cant',
#  'exactly',
#  'see',
#  'you',
#  'see',
#  'like',
#  'a',
#  'branches',
#  'rustling',
#  'and',
#  'you',
#  'throw',
#  'your',
#  'axe',
#  'in',
#  'that',
#  'direction',
#  'and',
#  'you',
#  'hear',
#  'gerblin',
#  'just',
#  'barely',
#  'you',
#  'throw',
#  'it',
#  'into',
#  'the',
#  'woods',
#  'you',
#  'cant',
#  'exactly',
#  'see',
#  'you',
#  'see',
#  'like',
#  'a',
#  'branches',
#  'rustling',
#  'and',
#  'you',
#  'throw',
#  'your',
#  'axe',
#  'in',
#  'that',
#  'direction',
#  'and',
#  'you',
#  'hear',
#  'gerblin',
#  'just',
#  'barely',
#  'you',
#  'throw',
#  'it',
#  'into',
#  'the',
#  'woods',
#  'you',
#  'cant',
#  'exactly',
#  'see',
#  'you',
#  'see',
#  'like',
#  'a',
#  'branches',
#  'rustling',
#  'and',
#  'you',
#  'throw',
#  'your',
#  'axe',
#  'in',
#  'that',
#  'direction',
#  'and',
#  'you',
#  'hear',
#  'gerblin',
#  'just',
#  'barely',
#  'you',
#  'throw',
#  'it',
#  'into',
#  'the',
#  'woods',
#  'you',
#  'cant',
#  'exactly',
#  'see',
#  'you',
#  'see',
#  'like',
#  'a',
#  'branches',
#  'rustling',
#  'and',
#  'you',
#  'throw',
#  'your',
#  'axe',
#  'in',
#  'that',
#  'direction',
#  'and',
#  'you',
#  'hear',
#  'gerblin',
#  'were',
#  'here',
#  'a',
#  'wave',
#  'of',
#  'bats',
#  'taako',
#  'excellent',
#  'comes',
#  'pouring',
#  'out',
#  'a',
#  'wave',
#  'of',
#  'gas',
#  'bats',
#  'bats',
#  'bats',
#  'bats',
#  'baseball',
#  'bats',
#  'do',
#  'the',
#  'bats',
#  'have',
#  'gas',
#  'they',
#  'definitely',
#  'do',
#  'yeah',
#  'draw',
#  'closer',
#  'to',
#  'them',
#  'they',
#  'seem',
#  'more',
#  'agitated',
#  'couple',
#  'of',
#  'them',
#  'are',
#  'snarling',
#  'at',
#  'you',
#  'now',
#  'uh',
#  'they',
#  'are',
#  'but',
#  'theres',
#  'nothing',
#  'else',
#  'in',
#  'the',
#  'room',
#  'other',
#  'than',
#  'these',
#  'wolves',
#  'so',
#  'theres',
#  'some',
#  'wolves',
#  'down',
#  'there',
#  'it',
#  'doesnt',
#  'seem',
#  'like',
#  'its',
#  'worth',
#  'it',
#  'lets',
#  'keep',
#  'going',
#  'taako',
#  'excellent',
#  'well',
#  'i',
#  'trust',
#  'your',
#  'judgement',
#  'okay',
#  'im',
#  'into',
#  'that',
#  'off',
#  'we',
#  'go',
#  'can',
#  'alright',
#  'i',
#  'will',
#  'climb',
#  'i',
#  'i',
#  'will',
#  'climb',
#  'what',
#  'do',
#  'i',
#  'need',
#  'to',
#  'do',
#  'uh',
#  'you',
#  'will',
#  'make',
#  'a',
#  'im',
#  'gonna',
#  'try',
#  'to',
#  'climb',
#  'up',
#  'to',
#  'the',
#  'overpass',
#  'the',
#  'bridge',
#  'is',
#  'relatively',
#  'rickety',
#  'its',
#  'of',
#  'gerblin',
#  'uh',
#  'construction',
#  'so',
#  'its',
#  'not',
#  'amazing',
#  'but',
#  'it',
#  'looks',
#  'like',
#  'itll',
#  'hold',
#  'your',
#  'weight',
#  'okay',
#  'so',
#  'i',
#  'roll',
#  'a',
#  '20',
#  'sided',
#  'die',
#  'it',
#  'looks',
#  'like',
#  'itll',
#  'hold',
#  'your',
#  'weight',
#  'okay',
#  'so',
#  'i',
#  'roll',
#  'a',
#  '20',
#  'sided',
#  'die',
#  'you',
#  'roll',
#  'a',
#  '20',
#  'sided',
#  'die',
#  'and',
#  'you',
#  'add',
#  'your',
#  'uh',
#  'your',
#  'athletics',
#  'dice',
#  'roll',
#  'does',
#  'that',
#  'sound',
#  'funny',
#  'talking',
#  'at',
#  'the',
#  'same',
#  'time',
#  'as',
#  'because',
#  'of',
#  'the',
#  'character',
#  'talking',
#  'at',
#  'the',
#  'same',
#  'time',
#  ...]

# %%
bar_graphic(lista_ocorrencias = flat_list)

# %%
bar_graphic(lista_ocorrencias = filtered_flat_list, max=30)

# %%
list_slice = list_df[0:11]
list_slice
# Out:
# ['going weekly for the rest of the experimental arcs [ Woohoo!] starting this week. So, um, I guess actually we have an episode— I hope we don’t screw it up!',
#  'by, like, logic, you know what I mean? So I can’t be like, “I wanna Help Out by…” [inhaling sharply through teeth] Ssssssssssssss... Ooooh, logic. “...pulling the sun down.” Yeah.',
#  'success, you open yourself up to repercussions. To, like, the same reper— so you can help out, yeah, but you are also exposing yourself to danger, which is real smart.',
#  'success, you open yourself up to repercussions. To, like, the same reper— so you can help out, yeah, but you are also exposing yourself to danger, which is real smart.',
#  'play in the NFL!” and he was like “No.” There’s some really- we haven’t— I really like this idea of a Chosen that’s just like [crosstalk] “No, no thank you!”',
#  'you are dealing with the consequences of your own spellcasting. That’s definitely this. Um. Yeah so- but if it’s Weird, I rolled an eight plus two so it’s a 10.',
#  "booze in a Arnold Palmer. I mean, sometimes there is. Arnold Palmer loves to party. [ and laugh] That's true, yeah. [chuckles] Sometimes there is booze in an Arnold. [Laughter]",
#  "no. Yeah, so go ahead and mark experience. Yes, but don't you see? I don't want to have failed. [crosstalk] Did you think about it that way? [crosstalk] Mmm, interesting.",
#  'he’s kind of leaning backwards, shooting at the snake along the length of its watery body, and basically heading towards one of the big water slides, just away from them.',
#  'I just think it’s information we need. ’s gonna Investigate a Mystery. Ok. And… Roll plus Sharp. [ rolls] That’s very bad. [quietly] Shit. You did a bad job, Dad.',
#  'trying to wait this thing out-- Yeah, I think hiding is a wonderful choice; this is the choice to make. Is there a Hide Under Pressure? [laughing] Hide Under Bed?']

# %%
doc = nlp(list_slice[0])
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# going go VERB VBG ROOT xxxx True False
# weekly weekly ADV RB advmod xxxx True False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# rest rest NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# experimental experimental ADJ JJ amod xxxx True False
# arcs arc NOUN NNS pobj xxxx True False
# [ [ PUNCT -LRB- punct [ False False
# Woohoo Woohoo PROPN NNP npadvmod Xxxxx True False
# ! ! PUNCT . punct ! False False
# ] ] PUNCT -RRB- punct ] False False
# starting start VERB VBG advcl xxxx True False
# this this DET DT det xxxx True True
# week week NOUN NN npadvmod xxxx True False
# . . PUNCT . punct . False False
# So so ADV RB advmod Xx True True
# , , PUNCT , punct , False False
# um um INTJ UH intj xx True False
# , , PUNCT , punct , False False
# I I PRON PRP nsubj X True True
# guess guess VERB VBP ROOT xxxx True False
# actually actually ADV RB advmod xxxx True False
# we we PRON PRP nsubj xx True True
# have have VERB VBP ccomp xxxx True True
# an an DET DT det xx True True
# episode episode NOUN NN dobj xxxx True False
# — — PUNCT : punct — False False
# I I PRON PRP nsubj X True True
# hope hope VERB VBP ccomp xxxx True False
# we we PRON PRP nsubj xx True True
# do do AUX VBP aux xx True True
# n’t n’t PART RB neg x’x False True
# screw screw VERB VB ccomp xxxx True False
# it it PRON PRP dobj xx True True
# up up ADP RP prt xx True True
# ! ! PUNCT . punct ! False False

# %%
for token in doc:
    if not token.is_stop and token.pos_ in ("VERB", "NOUN"):
        print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
                token.shape_, token.is_alpha, token.is_stop)
# Out:
# going go VERB VBG ROOT xxxx True False
# rest rest NOUN NN pobj xxxx True False
# arcs arc NOUN NNS pobj xxxx True False
# starting start VERB VBG advcl xxxx True False
# week week NOUN NN npadvmod xxxx True False
# guess guess VERB VBP ROOT xxxx True False
# episode episode NOUN NN dobj xxxx True False
# hope hope VERB VBP ccomp xxxx True False
# screw screw VERB VB ccomp xxxx True False

# %%
len(list_df)
# Out:
# 56738

# %%
result_list = []
for i in list_df:
    doc = nlp(i)
    for token in doc:
        if not token.is_stop and token.pos_ in ("VERB", "NOUN"):
            result_list.append(token.text)

# %%
result_list[0]
# Out:
# 'going'

# %%
bar_graphic(lista_ocorrencias = result_list, max=30)

# %%
skill_list = list(CR_df['skill'].unique())

# %%
for skill in skill_list:
    df_skill = CR_df[CR_df['skill'].values == skill]
    list_skill = ' '.join(df_skill['backward_text'])
    bar_graphic(lista_ocorrencias = [i.split(" ") for i in list_skill])
#     print(skill)
#     print(len(df_skill))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-bddd87f0d16b> in <module>
#       2     df_skill = CR_df[CR_df['skill'].values == skill]
#       3     list_skill = ' '.join(df_skill['backward_text'])
# ----> 4     bar_graphic(lista_ocorrencias = [i.split(" ") for i in list_skill])
#       5 #     print(skill)
#       6 #     print(len(df_skill))
#
# <ipython-input-26-7eab5e07a1cd> in bar_graphic(dicionario, paleta, lista_ocorrencias, max, dim)
#       8         if lista_ocorrencias is not None:
#       9             # A lista é então convertida para dicionario através da função de ocorrencias
# ---> 10             dicionario = ocorrencias(lista_ocorrencias)
#      11
#      12     # O dicionario é transformado em dataframe para melhor manipulação
#
# <ipython-input-25-62078675ffa2> in ocorrencias(lista)
#       9     dict_ocorrencias = {}
#      10     for i in lista:
# ---> 11         if i in dict_ocorrencias:
#      12             dict_ocorrencias[i] += 1
#      13         else:
#
# TypeError: unhashable type: 'list'
